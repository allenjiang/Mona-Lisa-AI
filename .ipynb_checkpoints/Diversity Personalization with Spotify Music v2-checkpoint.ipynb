# %% [markdown]
# # Goal: build a model that will recommend a song that is outside of past preferences to diversify their taste in music

# %% [markdown]
# * Step 1: Get data
# * Step 2: Build status quo recommender system
# * Step 3: Evolve recommender system to diversity recommender

# %%
# Import libraries
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import time 
import json

# %%
# Connect to Spotify API
path_auth = '/Users/allenj/Documents/Keys/auth_spotify.json'
auth = json.loads(open(path_auth).read())

client_id = auth['client_id']
client_secret = auth['client_secret']

client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# Get song IDs from desired user's playlist
def getTrackIDs(user, playlist_id):
    ids = []
    playlist = sp.user_playlist(user, playlist_id)
    for item in playlist['tracks']['items']:
        track = item['track']
        ids.append(track['id'])
        ids.append(track['id'])
    return ids

ids = getTrackIDs('ajiang', '5PKZSKuHP4d27SXO5fB9Wl')

# %%
# Spotify doesn't expose track genre, it's only done through artist genre
# sp.artist('4QQgXkCYTt3BlENzhyNETg')['genres']

# %%
# Function to grab track data from song IDs
def getTrackFeatures(id):
  meta = sp.track(id)
  features = sp.audio_features(id)

  # meta
  name = meta['name']
  album = meta['album']['name']
  artist = meta['album']['artists'][0]['name']
  release_date = meta['album']['release_date']
  length = meta['duration_ms']
  popularity = meta['popularity']
  
  # features
  key = features[0]['key']
  mode = features[0]['mode']
  valence = features[0]['valence']
  acousticness = features[0]['acousticness']
  danceability = features[0]['danceability']
  energy = features[0]['energy']
  instrumentalness = features[0]['instrumentalness']
  liveness = features[0]['liveness']
  loudness = features[0]['loudness']
  speechiness = features[0]['speechiness']
  tempo = features[0]['tempo']
  time_signature = features[0]['time_signature']

  track = [name, album, artist, release_date, length, popularity, key, mode, valence, danceability, acousticness, danceability, energy, instrumentalness, liveness, loudness, speechiness, tempo, time_signature]
  return track

# %%
# Loop over tracks and apply the function
tracks = []
for i in range(len(ids)):
  time.sleep(.5)
  track = getTrackFeatures(ids[i])
  tracks.append(track)

# %%
# Create dataset
df = pd.DataFrame(tracks, columns = ['name', 'album', 'artist', 'release_date', 'length', 'popularity', 'key', 'mode', 'valence', 'danceability', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'time_signature'])

# %%
# Export to csv
df.to_csv('Data/spotify.csv', sep = ',')

# %%
# Load dataset for easier access
df = pd.read_csv('Data/spotify.csv')

# %% [markdown]
# # Explore data

# %%
df.head()
# Out:
#                 name              album               artist release_date  \
# 0  Girls in the Hood  Girls in the Hood  Megan Thee Stallion   2020-06-26
# 1  Girls in the Hood  Girls in the Hood  Megan Thee Stallion   2020-06-26
# 2         Pussy Talk       City On Lock           City Girls   2020-06-20
# 3         Pussy Talk       City On Lock           City Girls   2020-06-20
# 4              Float              Float                6LACK   2020-06-24
#
#    length  popularity  key  mode  valence  danceability  acousticness  \
# 0  154323          74    6     1    0.874         0.821       0.00824
# 1  154323          74    6     1    0.874         0.821       0.00824
# 2  218332          65    1     1    0.242         0.943       0.00160
# 3  218332          65    1     1    0.242         0.943       0.00160
# 4  178972          60   10     0    0.170         0.852       0.14600
#
#    danceability  energy  instrumentalness  liveness  loudness  speechiness  \
# 0         0.821   0.863               0.0    0.0377    -3.159       0.3530
# 1         0.821   0.863               0.0    0.0377    -3.159       0.3530
# 2         0.943   0.641               0.0    0.2110    -5.598       0.1910
# 3         0.943   0.641               0.0    0.2110    -5.598       0.1910
# 4         0.852   0.480               0.0    0.0872    -6.587       0.0635
#
#      tempo  time_signature
# 0  180.013               4
# 1  180.013               4
# 2   99.099               4
# 3   99.099               4
# 4  124.013               4

# %%
df.shape
# Out:
# (104, 19)

# %%
# Count number of unique artists
len(df['artist'].unique())
# Out:
# 46

# %% [markdown]
# # Create song recommender

# %%
from sklearn.model_selection import train_test_split

train_data, test_data = train_test_split(df, test_size = 0.20)
print(train_data.head())
# Out:
#                              name  \
# 17                    BULLETPROOF
# 15                      Discounts
# 95                          ENEMY
# 3                      Pussy Talk
# 39  Tommy Lee (feat. Post Malone)
#
#                                              album      artist release_date  \
# 17  IDK & FRIENDS 2 (Basketball County Soundtrack)         IDK   2020-06-26
# 15                                       Discounts    cupcakKe   2020-06-26
# 95                                           ENEMY    slowthai   2020-05-10
# 3                                     City On Lock  City Girls   2020-06-20
# 39                   Tommy Lee (feat. Post Malone)  Tyla Yaweh   2020-06-12
#
#     length  popularity  key  mode  valence  danceability  acousticness  \
# 17  183921          54    1     1    0.267         0.763       0.06410
# 15  176040          56    1     1    0.867         0.791       0.05770
# 95  148264          56    1     1    0.285         0.826       0.00995
# 3   218332          65    1     1    0.242         0.943       0.00160
# 39  224638          86   10     1    0.634         0.457       0.21800
#
#     danceability  energy  instrumentalness  liveness  loudness  speechiness  \
# 17         0.763   0.490            0.0000    0.0934   -10.832        0.132
# 15         0.791   0.810            0.0000    0.1160    -5.397        0.352
# 95         0.826   0.416            0.0087    0.1360    -8.214        0.192
# 3          0.943   0.641            0.0000    0.2110    -5.598        0.191
# 39         0.457   0.621            0.0000    0.0944    -5.923        0.138
#
#       tempo  time_signature
# 17  135.955               4
# 15  159.949               4
# 95  137.037               4
# 3    99.099               4
# 39   85.359               3

# %%
# Create an instance of popularity based recommender class
import Recommenders as Recommenders

pm = Recommenders.popularity_recommender_py()
pm.create(train_data, 'artist', 'name')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-56-2daffa5a313b> in <module>
#       1 # Create an instance of popularity based recommender class
# ----> 2 import Recommenders as Recommenders
#       3
#       4 pm = Recommenders.popularity_recommender_py()
#       5 pm.create(train_data, 'artist', 'name')
#
# ModuleNotFoundError: No module named 'Recommenders'

# %%
sklearn.externals
# Out:
# Collecting sklearn
#   Downloading https://files.pythonhosted.org/packages/1e/7a/dbb3be0ce9bd5c8b7e3d87328e79063f8b263b2b1bfa4774cb1147bfcd3f/sklearn-0.0.tar.gz
# Requirement already satisfied: scikit-learn in /Users/allenj/opt/anaconda3/lib/python3.7/site-packages (from sklearn) (0.23.1)
# Requirement already satisfied: numpy>=1.13.3 in /Users/allenj/opt/anaconda3/lib/python3.7/site-packages (from scikit-learn->sklearn) (1.17.2)
# Requirement already satisfied: scipy>=0.19.1 in /Users/allenj/opt/anaconda3/lib/python3.7/site-packages (from scikit-learn->sklearn) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /Users/allenj/opt/anaconda3/lib/python3.7/site-packages (from scikit-learn->sklearn) (0.13.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/allenj/opt/anaconda3/lib/python3.7/site-packages (from scikit-learn->sklearn) (2.0.0)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1316 sha256=7931015c4f4d1e53334349bfa7f666ccd59336b4d53605631f0ccbe5affd8d00
#   Stored in directory: /Users/allenj/Library/Caches/pip/wheels/76/03/bb/589d421d27431bcd2c6da284d5f2286c8e3b2ea3cf1594c074
# Successfully built sklearn
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install graphlab
# Out:
# Collecting graphlab
#   ERROR: Could not find a version that satisfies the requirement graphlab (from versions: none)
# ERROR: No matching distribution found for graphlab
# Note: you may need to restart the kernel to use updated packages.

# %%
import graphlab as gl
# set canvas to show sframes and sgraphs in ipython notebook
gl.canvas.set_target('ipynb')
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-70-342bdb0c1ec4> in <module>
# ----> 1 import graphlab as gl
#       2 # set canvas to show sframes and sgraphs in ipython notebook
#       3 gl.canvas.set_target('ipynb')
#       4 import matplotlib.pyplot as plt
#       5 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'graphlab'

# %%
import sklearn.external.joblib as extjoblib
import joblib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-68-fd74f5e07d68> in <module>
# ----> 1 import sklearn.external.joblib as extjoblib
#       2 import joblib
#
# ModuleNotFoundError: No module named 'sklearn.external'

# %%
# Find clusters in data
from sklearn.cluster import KMeans

music = df[['popularity','danceability','acousticness','danceability','energy','instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo']]
kmeans = KMeans(n_clusters = 2)
kmeans.fit(music)
y_means = kmeans.predict(music)
centers = kmeans.cluster_centers_

# %%
centers
# Out:
# array([[ 6.50555556e+01,  7.57277778e-01,  7.57277778e-01,
#          1.16341583e-01,  7.57277778e-01,  7.57277778e-01,
#          6.58500000e-01,  8.64749806e-03,  2.19966667e-01,
#         -6.03500000e+00,  1.86711111e-01,  1.39910583e+02],
#        [ 6.93125000e+01,  6.87500000e-01,  6.87500000e-01,
#          1.69155000e-01,  6.87500000e-01,  6.87500000e-01,
#          6.00500000e-01,  5.26655000e-04,  1.64856250e-01,
#         -7.25625000e+00,  1.94156250e-01,  9.02998125e+01]])

# %%
# Try another way
km = KMeans(n_clusters=5)
y_predicted = km.fit_predict(df[['popularity','danceability','acousticness','danceability','energy','instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo']])
y_predicted

# %%
df['cluster'] = y_predicted
df

# %%
df = df.sort_values(by ='cluster')
df

# %%
# Use PCA to find some type of pattern

# %%
# Calculate the covariance matrix
from sklearn.preprocessing import StandardScaler
features = ['danceability','acousticness','danceability','energy','instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo']

# Separate out the features
x = df.loc[:, features].values
y = df.loc[:, ['popularity']].values
x = StandardScaler().fit_transform(x)
x
# Out:
# array([[ 6.62955439e-01,  6.62955439e-01, -7.79792216e-01,
#          6.62955439e-01,  6.62955439e-01,  1.68439058e+00,
#         -2.56014780e-01, -1.06253338e+00,  1.55158262e+00,
#          1.28100216e+00,  2.07338570e+00],
#        [ 1.61234354e+00,  1.61234354e+00, -8.21430677e-01,
#          1.61234354e+00,  1.61234354e+00,  2.62229981e-03,
#         -2.56014780e-01,  5.13584788e-02,  3.87813070e-01,
#          1.56071394e-02, -9.56670378e-01],
#        [ 9.04193400e-01,  9.04193400e-01,  8.40804356e-02,
#          9.04193400e-01,  9.04193400e-01, -1.21703848e+00,
#         -2.56014780e-01, -7.44370386e-01, -8.40885618e-02,
#         -9.80305609e-01, -2.36944128e-02],
#        [ 4.04058620e-02,  4.04058620e-02, -7.03538649e-01,
#          4.04058620e-02,  4.04058620e-02,  2.82917013e-01,
#         -2.56014780e-01, -8.02218203e-01,  2.74728453e-01,
#          1.29662432e+00,  1.51515047e+00],
#        [ 1.30885063e+00,  1.30885063e+00, -4.35773244e-01,
#          1.30885063e+00,  1.30885063e+00,  6.23815989e-01,
#         -2.56014780e-01, -1.15757438e-01,  5.66267277e-01,
#          5.54571685e-01,  7.62710631e-01],
#        [-6.44398673e-01, -6.44398673e-01, -4.57721228e-01,
#         -6.44398673e-01, -6.44398673e-01, -3.23125610e-01,
#         -2.56014780e-01,  3.21314960e-01, -2.46796809e-01,
#         -5.93657130e-01, -1.56287632e+00],
#        [-1.23013402e-01, -1.23013402e-01, -4.76074687e-02,
#         -1.23013402e-01, -1.23013402e-01, -1.37612467e+00,
#         -2.56014780e-01, -8.89632683e-01,  4.70360070e-01,
#         -8.36581730e-01,  6.13031538e-01],
#        [-7.22217370e-01, -7.22217370e-01, -5.43004823e-01,
#         -7.22217370e-01, -7.22217370e-01, -3.23125610e-01,
#         -2.39526647e-01,  1.92819877e+00, -1.25600637e-01,
#          9.52936785e-01, -1.53995823e+00],
#        [-6.83308021e-01, -6.83308021e-01,  4.22911399e+00,
#         -6.83308021e-01, -6.83308021e-01, -2.35336840e+00,
#         -2.08965311e-01, -5.84967512e-01, -1.62576113e+00,
#         -9.49842395e-01,  3.88643965e-01],
#        [ 7.01864788e-01,  7.01864788e-01, -7.69069058e-01,
#          7.01864788e-01,  7.01864788e-01, -1.70187258e+00,
#          1.06224499e-01, -4.30706665e-01, -8.60412076e-01,
#          2.34182198e-02,  4.64026506e-01],
#        [ 4.91754305e-01,  4.91754305e-01,  1.51010572e-02,
#          4.91754305e-01,  4.91754305e-01,  3.88974472e-01,
#         -2.56014780e-01,  9.57640950e-01,  4.22645041e-01,
#          7.42037614e-01,  5.75096856e-01],
#        [-2.72993976e+00, -2.72993976e+00, -5.22938094e-01,
#         -2.72993976e+00, -2.72993976e+00,  4.64729800e-01,
#          2.51698935e+00,  3.66307706e-01,  1.51623679e-01,
#         -1.10372068e+00,  2.86186622e-01],
#        [ 4.81877317e-02,  4.81877317e-02,  1.34247256e-01,
#          4.81877317e-02,  4.81877317e-02,  2.52614882e-01,
#         -2.56014780e-01, -5.20692159e-01,  3.66818458e-01,
#         -2.73402834e-01,  5.70415874e-01],
#        [-4.42070060e-01, -4.42070060e-01, -8.05628129e-01,
#         -4.42070060e-01, -4.42070060e-01, -4.95323298e-03,
#         -2.56014780e-01,  3.92017847e-01, -1.57092555e-01,
#          9.52936785e-01,  9.41037337e-01]])

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents, columns = ['principal component 1', 'principal component 2'])
principalDf
# Out:
#     principal component 1  principal component 2
# 0               -2.195425              -1.990700
# 1               -3.126199               0.440078
# 2               -1.646471               1.422098
# 3               -0.693344              -0.555130
# 4               -2.823368              -0.438432
# 5                1.411301               0.393682
# 6                0.660208               2.386602
# 7               -1.357189              -1.119181
# 8               -0.326435               2.013400
# 9                2.544054              -2.236793
# 10               2.013585              -0.365835
# 11              -1.624344              -0.528707
# 12              -2.114058               0.694065
# 13               0.131741               0.729509
# 14               2.580300              -0.803834
# 15               0.101632              -1.595876
# 16              -1.414402              -0.505559
# 17               4.855696               1.870207
# 18              -0.587837               0.318834
# 19               4.358709               0.006427
# 20               6.043882               2.266044
# 21              -0.548435              -0.559148
# 22              -1.530939              -1.909428
# 23               1.581288              -1.861860
# 24              -0.398653               1.266710
# 25              -1.213506               0.131089
# 26              -3.162277               1.176696
# 27               0.930338               2.272134
# 28               2.226471              -1.578596
# 29               0.642969              -2.666474
# 30              -1.436819               0.441586
# 31              -2.749874               1.489701
# 32              -2.271071              -0.965274
# 33               0.646836              -0.406812
# 34              -0.048450              -1.280955
# 35               0.608240              -2.137528
# 36              -0.086014               0.950601
# 37              -0.424525              -3.085193
# 38               1.071916               0.705773
# 39               0.655427               1.608659
# 40              -1.611124               1.903467
# 41              -3.184485               0.388738
# 42              -1.185300               1.208170
# 43              -0.709892              -0.543008
# 44              -1.554389               0.216158
# 45               1.576593              -0.204379
# 46               2.626771               3.228129
# 47              -1.461182               1.550374
# 48              -1.049773              -0.648871
# 49               5.080682              -2.346609
# 50              -0.251346              -0.222123
# 51               0.438484              -0.522630

# %%
finalDf = pd.concat([principalDf, df[['popularity']]], axis = 1)
finalDf
# Out:
#     principal component 1  principal component 2  popularity
# 0               -2.195425              -1.990700          72
# 1               -3.126199               0.440078          65
# 2               -1.646471               1.422098          61
# 3               -0.693344              -0.555130          73
# 4               -2.823368              -0.438432          81
# 5                1.411301               0.393682          53
# 6                0.660208               2.386602          65
# 7               -1.357189              -1.119181          54
# 8               -0.326435               2.013400          52
# 9                2.544054              -2.236793          80
# 10               2.013585              -0.365835          85
# 11              -1.624344              -0.528707          50
# 12              -2.114058               0.694065          62
# 13               0.131741               0.729509          80
# 14               2.580300              -0.803834          66
# 15               0.101632              -1.595876          72
# 16              -1.414402              -0.505559          81
# 17               4.855696               1.870207          58
# 18              -0.587837               0.318834          44
# 19               4.358709               0.006427          86
# 20               6.043882               2.266044          69
# 21              -0.548435              -0.559148          79
# 22              -1.530939              -1.909428          64
# 23               1.581288              -1.861860          79
# 24              -0.398653               1.266710          91
# 25              -1.213506               0.131089          72
# 26              -3.162277               1.176696          78
# 27               0.930338               2.272134          71
# 28               2.226471              -1.578596          84
# 29               0.642969              -2.666474          51
# 30              -1.436819               0.441586          50
# 31              -2.749874               1.489701          59
# 32              -2.271071              -0.965274          80
# 33               0.646836              -0.406812          79
# 34              -0.048450              -1.280955          66
# 35               0.608240              -2.137528          94
# 36              -0.086014               0.950601          62
# 37              -0.424525              -3.085193          60
# 38               1.071916               0.705773          65
# 39               0.655427               1.608659          67
# 40              -1.611124               1.903467          65
# 41              -3.184485               0.388738          75
# 42              -1.185300               1.208170          54
# 43              -0.709892              -0.543008          86
# 44              -1.554389               0.216158          79
# 45               1.576593              -0.204379          63
# 46               2.626771               3.228129          53
# 47              -1.461182               1.550374          56
# 48              -1.049773              -0.648871          57
# 49               5.080682              -2.346609          38
# 50              -0.251346              -0.222123          52
# 51               0.438484              -0.522630          13

# %%
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
fig = plt.figure()
ax = plt.axes(projection='3d')

# %%
ax = plt.axes(projection='3d')

# Data for three-dimensional scattered points
zdata = finalDf['principal component 1']
xdata = finalDf['principal component 2']
ydata = finalDf['popularity']
ax.scatter3D(xdata, ydata, zdata, c=zdata);

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# Splitting the data into training and test set
X = finalDf[['principal component 1', 'principal component 2']]
y = finalDf['popularity']

# Use Bag-of-words features
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
linreg = LinearRegression()
linreg.fit(X_train, y_train)
prediction = linreg.predict(X_test)

# %%
linreg.fit(X, y)
print('Coefficient:', linreg.coef_, 'Intercept:', linreg.intercept_)
print('R^2:', linreg.score(X, y))
# Out:
# Coefficient: [-0.29098063 -1.1036461 ] Intercept: 66.36538461538461
# R^2: 0.013604054778555197

# %%
X = df.loc[:, features]
y = df.loc[:, ['popularity']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
linreg = LinearRegression()
linreg.fit(X_train, y_train)
prediction = linreg.predict(X_test)

# %%
linreg.fit(X, y)
print('Coefficient:', linreg.coef_, 'Intercept:', linreg.intercept_)
print('R^2:', linreg.score(X, y))

# %%
pip install xgboost

# %%
import xgboost as xgb
from xgboost.sklearn import XGBRegressor

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=7)
model = XGBRegressor()
model.fit(X_train, y_train)
# make predictions for test data
y_pred = model.predict(X_test)
accuracy = model.score(X_test, y_test)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# <ipython-input-3-330f4c2c96d9> in <module>
# ----> 1 import xgboost as xgb
#       2 from xgboost.sklearn import XGBRegressor
#       3
#       4 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=7)
#       5 model = XGBRegressor()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/xgboost/__init__.py in <module>
#       9 import warnings
#      10
# ---> 11 from .core import DMatrix, DeviceQuantileDMatrix, Booster
#      12 from .training import train, cv
#      13 from . import rabit  # noqa
#
# ~/opt/anaconda3/lib/python3.7/site-packages/xgboost/core.py in <module>
#     173
#     174 # load the XGBoost library globally
# --> 175 _LIB = _load_lib()
#     176
#     177
#
# ~/opt/anaconda3/lib/python3.7/site-packages/xgboost/core.py in _load_lib()
#     164             '`brew install libomp` to install OpenMP runtime.\n' +
#     165             '  * You are running 32-bit Python on a 64-bit OS\n' +
# --> 166             'Error message(s): {}\n'.format(os_error_list))
#     167     lib.XGBGetLastError.restype = ctypes.c_char_p
#     168     lib.callback = _get_log_callback_func()
#
# XGBoostError: XGBoost Library (libxgboost.dylib) could not be loaded.
# Likely causes:
#   * OpenMP runtime is not installed (vcomp140.dll or libgomp-1.dll for Windows, libomp.dylib for Mac OSX, libgomp.so for Linux and other UNIX-like OSes). Mac OSX users: Run `brew install libomp` to install OpenMP runtime.
#   * You are running 32-bit Python on a 64-bit OS
# Error message(s): ['dlopen(/Users/allenj/opt/anaconda3/lib/python3.7/site-packages/xgboost/lib/libxgboost.dylib, 6): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib\n  Referenced from: /Users/allenj/opt/anaconda3/lib/python3.7/site-packages/xgboost/lib/libxgboost.dylib\n  Reason: image not found']

# %%
# Trying something

# Since this code was ran several times over the course of this project, I shuffled songsdf each time to 
# reduce the likelihood of getting duplicates in my overall data once it's merged together.
songsdf = shuffle(songsdf)

progcounter, updatecounter, totalcount = 0, 0, 0
length = len(songsdf)

for index, row in songsdf.iterrows():
    # Get the artist, track, and genre of each song in songsdf
    artist = row['artist'].strip()
    track = row['song'].strip()
    genre = row['genre']

    progcounter += 1
    updatecounter += 1
    
    # Search for song, get the first result's id
    results = sp.search(artist + ' ' + track)
    
    try:
        track_id = results['tracks']['items'][0]['id']
        # Use id to find audio features of song
        features = sp.audio_features(tracks = [track_id])
        
        # Parse features to find each attribute
        danceability = features[0]['danceability']
        energy = features[0]['energy']
        key = features[0]['key']
        loudness = features[0]['loudness']
        mode = features[0]['mode']
        speechiness = features[0]['speechiness']
        acousticness = features[0]['acousticness']
        instrumentalness = features[0]['instrumentalness']
        liveness = features[0]['liveness']
        valence = features[0]['valence']
        tempo = features[0]['tempo']
        duration_ms = features[0]['duration_ms']
        time_signature = features[0]['time_signature']
        
        # Create a new row to be added to attrdf, then add it
        cols = [track, artist, genre, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, duration_ms, time_signature]
        attrdf.loc[totalcount] = cols
        totalcount += 1
    except:
        pass
    
    # Progress counter
    if updatecounter == 500:
        updatecounter = 0
        print('----    progress: {0:.3g}%, song count:'.format(progcounter/length), totalcount)

print('Done -', totalcount, 'songs added.')


# Commented out code below saves attrdf to a csv file, this way we can use 
# data gathered from this notebook in other notebooks

# attrdf.to_csv('songfeaturedata.csv', encoding='utf-8', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-06d2bb25faed> in <module>
#       3 # Since this code was ran several times over the course of this project, I shuffled songsdf each time to
#       4 # reduce the likelihood of getting duplicates in my overall data once it's merged together.
# ----> 5 songsdf = shuffle(songsdf)
#       6
#       7 progcounter, updatecounter, totalcount = 0, 0, 0
#
# NameError: name 'shuffle' is not defined

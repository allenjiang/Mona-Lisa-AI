# %% [markdown]
# # Goal is to answer the question: can a machine detect a person's gender based on their tweet?

# %% [markdown]
# Steps:
# 1. Get twitter data
# 2. Clean
# 3. Analyze and visualize
# 4. Build model
# 5. Test model

# %%
# Import libraries
import numpy as np
import pandas as pd
import tweepy as tw
import seaborn as sns
import json
import pprint
from matplotlib import pyplot as plt

# Import libraries for WordCloud
from wordcloud import WordCloud,ImageColorGenerator
from PIL import Image
import urllib
import requests

import nltk
from nltk import PorterStemmer
import textblob
from textblob import TextBlob
import re
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix, classification_report,accuracy_score

# %%
# Connect to twitter API
path_auth = '/Users/allenj/Documents/Keys/auth_twitter.json'
auth = json.loads(open(path_auth).read())
pp = pprint.PrettyPrinter(indent=4)

my_consumer_key = auth['my_consumer_key']
my_consumer_secret = auth['my_consumer_secret']
my_access_token = auth['your_access_token']
my_access_token_secret = auth['my_access_token_secret']

auth = tw.OAuthHandler(my_consumer_key, my_consumer_secret)
auth.set_access_token(my_access_token, my_access_token_secret)
api = tw.API(auth)

type(api)
# Out:
# tweepy.api.API

# %% [markdown]
# # 1. Get Twitter data

# %%
# Upload list of desired users
# Gender 0 = male, 1 = female
users = pd.read_csv('../Data/users.csv')
users
# Out:
#                user                 name  gender  followers_millions  \
# 0       BarackObama         Barack Obama       0                 118
# 1      justinbieber        Justin Bieber       0                 111
# 2         katyperry           Katy Perry       1                 108
# 3           rihanna              Rihanna       1                  96
# 4     taylorswift13         Taylor Swift       1                  86
# 5         Cristiano    Cristiano Ronaldo       0                  84
# 6          ladygaga            Lady Gaga       1                  81
# 7   realDonaldTrump         Donald Trump       0                  80
# 8      TheEllenShow      Ellen DeGeneres       1                  80
# 9      ArianaGrande        Ariana Grande       1                  74
# 10    KimKardashian       Kim Kardashian       1                  65
# 11      jtimberlake    Justin Timberlake       0                  64
# 12      selenagomez         Selena Gomez       1                  61
# 13     narendramodi        Narendra Modi       0                  57
# 14    britneyspears       Britney Spears       1                  56
# 15         ddlovato            Team Demi       1                  55
# 16          shakira              Shakira       1                  52
# 17      jimmyfallon         Jimmy Fallon       0                  51
# 18        BillGates           Bill Gates       0                  50
# 19         neymarjr               Neymar       0                  47
# 20        KingJames         LeBron James       0                  46
# 21              JLo       Jennifer Lopez       1                  45
# 22       MileyCyrus          Miley Cyrus       1                  44
# 23        BrunoMars           Bruno Mars       0                  43
# 24            Oprah        Oprah Winfrey       1                  43
# 25       SrBachchan     Amitabh Bachchan       0                  42
# 26  BeingSalmanKhan          Salman Khan       0                  40
# 27           iamsrk       Shah Rukh Khan       0                  40
# 28    NiallOfficial          Niall Horan       0                  39
# 29            Drake                Drake       0                  39
# 30      akshaykumar         Akshay Kumar       0                  36
# 31       wizkhalifa          Wiz Khalifa       0                  36
# 32   KevinHart4real           Kevin Hart       0                  36
# 33         imVkohli          Virat Kohli       0                  35
# 34       LilTunechi            Lil Wayne       0                  34
# 35         elonmusk            Elon Musk       0                  34
# 36     Harry_Styles         Harry Styles       0                  34
# 37  Louis_Tomlinson      Louis Tomlinson       0                  33
# 38       aliciakeys          Alicia Keys       1                  30
# 39       EmmaWatson          Emma Watson       1                  29
# 40   HillaryClinton      Hillary Clinton       1                  28
# 41            Adele                Adele       1                  27
# 42   priyankachopra             PRIYANKA       1                  26
# 43  kourtneykardash  Kourtney Kardashian       1                  25
# 44     AvrilLavigne        Avril Lavigne       1                  21
# 45      MariahCarey         Mariah Carey       1                  21
# 46    AnushkaSharma       Anushka Sharma       1                  21
# 47       NICKIMINAJ           Mrs. Petty       1                  20
#
#                                      activity         country
# 0                       Former U.S. president   United States
# 1                                    Musician          Canada
# 2                                    Musician   United States
# 3                  Musician and businesswoman        Barbados
# 4                                    Musician   United States
# 5                                  Footballer        Portugal
# 6                        Musician and actress   United States
# 7                      Current U.S. president   United States
# 8             Comedian and television hostess   United States
# 9                        Musician and actress   United States
# 10   Television personality and businesswoman   United States
# 11                         Musician and actor   United States
# 12                       Musician and actress   United States
# 13            Current Prime Minister of India           India
# 14                                   Musician   United States
# 15                                   Musician   United States
# 16                                   Musician        Colombia
# 17                                   Comedian   United States
# 18             Businessman and philanthropist   United States
# 19                                 Footballer          Brazil
# 20                          Basketball player   United States
# 21                       Musician and actress   United States
# 22                       Musician and actress   United States
# 23                                   Musician   United States
# 24   Television personality and businesswoman   United States
# 25                                      Actor           India
# 26                    Actor and film producer           India
# 27                    Actor and film producer           India
# 28                                   Musician         Ireland
# 29                                     Rapper          Canada
# 30                                      Actor           India
# 31                                     Rapper   United States
# 32                         Comedian and actor   United States
# 33                                  Cricketer           India
# 34                                     Rapper   United States
# 35  Industrial designer and tech entrepreneur    South Africa
# 36                                   Musician  United Kingdom
# 37                                   Musician  United Kingdom
# 38                                   Musician   United States
# 39                                      Actor   United States
# 40                                 Politician   United States
# 41                                   Musician  United Kingdom
# 42   Television personality and businesswoman           India
# 43   Television personality and businesswoman   United States
# 44                                   Musician   United States
# 45                                   Musician   United States
# 46   Television personality and businesswoman           India
# 47                                   Musician   United States

# %%
# Get collection of tweets from these usernames and store it into a new dataframe
list = []

for index, row in users.iterrows():
    tweets = api.user_timeline(screen_name=row['user'], count=20, include_rts=False)
    users_text = [[tweet.user.screen_name, tweet.text, row['gender']] for tweet in tweets]
    tweet_text = pd.DataFrame(data=users_text, 
                        columns=["user", "text", "gender"])
    list.append(tweet_text)

# Merge the list    
tweets = pd.concat(list) 
tweets
# Out:
#            user                                               text  gender
# 0   BarackObama  My statement on the death of George Floyd: htt...       0
# 1   BarackObama  If you believe in a more just, more generous, ...       0
# 2   BarackObama  On Memorial Day, we honor those who gave all f...       0
# 3   BarackObama  And here’s more on the approach Sweden has tak...       0
# 4   BarackObama  South Korea has focused on testing to guard ag...       0
# ..          ...                                                ...     ...
# 15   NICKIMINAJ  That real ass ain’t keep yo n*gga hooooome. No...       1
# 16   NICKIMINAJ  Ummm during the quarantine? I would if they ma...       1
# 17   NICKIMINAJ  There are def a few hidden messages in the rem...       1
# 18   NICKIMINAJ  Ummmm lol not a chance in hell 🤣 https://t.co/...       1
# 19   NICKIMINAJ  I prefer the outro but I love the beat on the ...       1
#
# [758 rows x 3 columns]

# %%
# Count the number of datapoints per person
tweets.groupby(["user", "gender"]).size()
# Out:
# user             gender
# Adele            1         18
# AnushkaSharma    1         16
# ArianaGrande     1         12
# AvrilLavigne     1         12
# BarackObama      0         19
# BeingSalmanKhan  0         20
# BillGates        0         17
# BrunoMars        0         19
# Cristiano        0         20
# Drake            0          6
# EmmaWatson       1          3
# Harry_Styles     0         19
# HillaryClinton   1         18
# JLo              1         14
# KevinHart4real   0         11
# KimKardashian    1         17
# KingJames        0         14
# LilTunechi       0         19
# Louis_Tomlinson  0         20
# MariahCarey      1          9
# MileyCyrus       1         12
# NICKIMINAJ       1         20
# NiallOfficial    0         16
# Oprah            1         15
# SrBachchan       0         20
# TheEllenShow     1         19
# akshaykumar      0         18
# aliciakeys       1         18
# britneyspears    1         11
# ddlovato         1          9
# elonmusk         0         13
# iamsrk           0         20
# imVkohli         0         19
# jimmyfallon      0         18
# jtimberlake      0         12
# justinbieber     0         15
# katyperry        1         20
# kourtneykardash  1         18
# ladygaga         1         20
# narendramodi     0         20
# neymarjr         0         18
# priyankachopra   1         18
# realDonaldTrump  0         10
# rihanna          1         19
# selenagomez      1         13
# shakira          1         12
# taylorswift13    1         20
# wizkhalifa       0         12
# dtype: int64

# %% [markdown]
# # Clean text

# %%
# Clean text by removing things
def remove_pattern(text,pattern):
    
    # re.findall() finds the pattern i.e @user and puts it in a list for further task
    r = re.findall(pattern,text)
    
    # re.sub() removes @user from the sentences in the dataset
    for i in r:
        text = re.sub(i,"",text)
    
    return text

#Remove @ symbol, URL links, and "&amp;"
tweets['clean_text'] = np.vectorize(remove_pattern)(tweets['text'], "@[\w]*")
tweets['clean_text'] = np.vectorize(remove_pattern)(tweets['clean_text'], "https?:\/\/.*[\r\n]*")
tweets['clean_text'] = np.vectorize(remove_pattern)(tweets['clean_text'], "&amp;")
tweets
# Out:
#            user                                               text  gender  \
# 0   BarackObama  My statement on the death of George Floyd: htt...       0
# 1   BarackObama  If you believe in a more just, more generous, ...       0
# 2   BarackObama  On Memorial Day, we honor those who gave all f...       0
# 3   BarackObama  And here’s more on the approach Sweden has tak...       0
# 4   BarackObama  South Korea has focused on testing to guard ag...       0
# ..          ...                                                ...     ...
# 15   NICKIMINAJ  That real ass ain’t keep yo n*gga hooooome. No...       1
# 16   NICKIMINAJ  Ummm during the quarantine? I would if they ma...       1
# 17   NICKIMINAJ  There are def a few hidden messages in the rem...       1
# 18   NICKIMINAJ  Ummmm lol not a chance in hell 🤣 https://t.co/...       1
# 19   NICKIMINAJ  I prefer the outro but I love the beat on the ...       1
#
#                                            clean_text
# 0         My statement on the death of George Floyd:
# 1   If you believe in a more just, more generous, ...
# 2   On Memorial Day, we honor those who gave all f...
# 3   And here’s more on the approach Sweden has tak...
# 4   South Korea has focused on testing to guard ag...
# ..                                                ...
# 15  That real ass ain’t keep yo n*gga hooooome. No...
# 16  Ummm during the quarantine? I would if they ma...
# 17  There are def a few hidden messages in the rem...
# 18                  Ummmm lol not a chance in hell 🤣
# 19  I prefer the outro but I love the beat on the ...
#
# [758 rows x 4 columns]

# %%
# Remove punctuation, numbers, and special characters
tweets['clean_text'] = tweets['clean_text'].str.replace("[^a-zA-Z#]", " ")
tweets.head(10)
# Out:
#            user                                               text  gender  \
# 0   BarackObama  My statement on the death of George Floyd: htt...       0
# 1   BarackObama  If you believe in a more just, more generous, ...       0
# 2   BarackObama  On Memorial Day, we honor those who gave all f...       0
# 3   BarackObama  And here’s more on the approach Sweden has tak...       0
# 4   BarackObama  South Korea has focused on testing to guard ag...       0
# 0  justinbieber         Thank you @angela_rye for the conversation       0
# 1  justinbieber                       Live https://t.co/WUjCacT9ae       0
# 2  justinbieber           In these streets https://t.co/Z1TtKLg2Q3       0
# 3  justinbieber  Make your own #StuckwithU merch https://t.co/F...       0
# 0     katyperry  Some of u with sharp ears caught a glimpse of ...       1
#
#                                           clean_text
# 0        My statement on the death of George Floyd
# 1  If you believe in a more just  more generous  ...
# 2  On Memorial Day  we honor those who gave all f...
# 3  And here s more on the approach Sweden has tak...
# 4  South Korea has focused on testing to guard ag...
# 0                    Thank you  for the conversation
# 1                                              Live
# 2                                  In these streets
# 3                   Make your own #StuckwithU merch
# 0  Some of u with sharp ears caught a glimpse of ...

# %%
# Remove short words less than 2
tweets['clean_text'] = tweets['clean_text'].apply(lambda x: ' '.join([w for w in x.split() if len(w)>3]))
tweets.head(10)
# Out:
#            user                                               text  gender  \
# 0   BarackObama  My statement on the death of George Floyd: htt...       0
# 1   BarackObama  If you believe in a more just, more generous, ...       0
# 2   BarackObama  On Memorial Day, we honor those who gave all f...       0
# 3   BarackObama  And here’s more on the approach Sweden has tak...       0
# 4   BarackObama  South Korea has focused on testing to guard ag...       0
# 0  justinbieber         Thank you @angela_rye for the conversation       0
# 1  justinbieber                       Live https://t.co/WUjCacT9ae       0
# 2  justinbieber           In these streets https://t.co/Z1TtKLg2Q3       0
# 3  justinbieber  Make your own #StuckwithU merch https://t.co/F...       0
# 0     katyperry  Some of u with sharp ears caught a glimpse of ...       1
#
#                                           clean_text
# 0                       statement death George Floyd
# 1  believe more just more generous more democrati...
# 2  Memorial honor those gave That takes different...
# 3  here more approach Sweden taken which differs ...
# 4  South Korea focused testing guard against outb...
# 0                                 Thank conversation
# 1                                               Live
# 2                                      these streets
# 3                        Make your #StuckwithU merch
# 0  Some with sharp ears caught glimpse this remix...

# %%
# Tokenization
tokenized_tweet = tweets['clean_text'].apply(lambda x: x.split())
tokenized_tweet.head()
# Out:
# 0                    [statement, death, George, Floyd]
# 1    [believe, more, just, more, generous, more, de...
# 2    [Memorial, honor, those, gave, That, takes, di...
# 3    [here, more, approach, Sweden, taken, which, d...
# 4    [South, Korea, focused, testing, guard, agains...
# Name: clean_text, dtype: object

# %%
# # Stemming
# ps = PorterStemmer()
# tokenized_tweet = tokenized_tweet.apply(lambda x: [ps.stem(i) for i in x])
# tokenized_tweet.head()
# Out:
# 0                     [statement, death, georg, floyd]
# 1    [believ, more, just, more, gener, more, democr...
# 2    [memori, honor, those, gave, that, take, diffe...
# 3    [here, more, approach, sweden, taken, which, d...
# 4    [south, korea, focus, test, guard, against, ou...
# Name: clean_text, dtype: object

# %%
# # Stich tokens back together
# for i in range(len(tokenized_tweet)):
#     tokenized_tweet[i] = ' '.join(str(tokenized_tweet[i]))
          
# tweets['clean_text'] = tokenized_tweet
# tweets.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-153-9d9206949d46> in <module>
#       1 # Stich tokens back together
#       2 for i in range(len(tokenized_tweet)):
# ----> 3     tokenized_tweet[i] = ' '.join(str(tokenized_tweet[i]))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#    1066         key = com.apply_if_callable(key, self)
#    1067         try:
# -> 1068             result = self.index.get_value(self, key)
#    1069
#    1070             if not is_scalar(result):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4728         k = self._convert_scalar_indexer(k, kind="getitem")
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
#    4732             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._maybe_get_bool_indexer()
#
# KeyError: 5

# %%
tweets['clean_text']
# Out:
# 0                         statement death George Floyd
# 1    believe more just more generous more democrati...
# 2    Memorial honor those gave That takes different...
# 3    here more approach Sweden taken which differs ...
# 4    South Korea focused testing guard against outb...
#                            ...
# 0
# 1    full quarantine hiatus mode social media clue ...
# 2    guess never answered this guys chatting text f...
# 3
# 4    love much Barbz just just never cease amaze ne...
# Name: clean_text, Length: 192, dtype: object

# %% [markdown]
# # 2. Exploratory data analysis

# %%
tweets['length'] = tweets['text'].apply(len)
fig1 = sns.barplot('gender', 'length', data=tweets)
plt.title('Average tweet length by gender')
# Out:
# Text(0.5, 1.0, 'Average tweet length by gender')

# %%
fig2 = sns.countplot(x='gender', data=tweets)
plt.title('Gender counts')
# Out:
# Text(0.5, 1.0, 'Gender counts')

# %% [markdown]
# # 3. Clean up data

# %%
def form_sentence(tweet):
    tweet_blob = TextBlob(tweet)
    return ' '.join(tweet_blob.words)

print(form_sentence(tweets['text'].iloc[10]))
print(tweets['text'].iloc[10])
# Out:
# Graduating is a big achievement no matter what but with all that the Class of 2020 has dealt with to get across th… https t.co/nuR3SUdo8F
# Graduating is a big achievement no matter what, but with all that the Class of 2020 has dealt with to get across th… https://t.co/nuR3SUdo8F

# %%
def no_user_alpha(tweet):
    tweet_list = [ele for ele in tweet.split() if ele != 'user']
    clean_tokens = [t for t in tweet_list if re.match(r'[^\W\d]*$', t)]
    clean_s = ' '.join(clean_tokens)
    clean_mess = [word for word in clean_s.split() if word.lower() not in stopwords.words('english')]
    return clean_mess
print(no_user_alpha(form_sentence(tweets['text'].iloc[10])))
print(tweets['text'].iloc[10])
# Out:
# ['Graduating', 'big', 'achievement', 'matter', 'Class', 'dealt', 'get', 'across', 'https']
# Graduating is a big achievement no matter what, but with all that the Class of 2020 has dealt with to get across th… https://t.co/nuR3SUdo8F

# %%
def normalization(tweet_list):
        lem = WordNetLemmatizer()
        normalized_tweet = []
        for word in tweet_list:
            normalized_text = lem.lemmatize(word,'v')
            normalized_tweet.append(normalized_text)
        return normalized_tweet
    
print(normalization(tweet_list))
tweets
# Out:
# ['I', 'be', 'play', 'with', 'my', 'friends', 'with', 'whom', 'I', 'use', 'to', 'play,', 'when', 'you', 'call', 'me', 'yesterday']
#            user                                               text  gender  \
# 0   BarackObama  My statement on the death of George Floyd: htt...       0
# 1   BarackObama  If you believe in a more just, more generous, ...       0
# 2   BarackObama  On Memorial Day, we honor those who gave all f...       0
# 3   BarackObama  And here’s more on the approach Sweden has tak...       0
# 4   BarackObama  South Korea has focused on testing to guard ag...       0
# ..          ...                                                ...     ...
# 15   NICKIMINAJ  That real ass ain’t keep yo n*gga hooooome. No...       1
# 16   NICKIMINAJ  Ummm during the quarantine? I would if they ma...       1
# 17   NICKIMINAJ  There are def a few hidden messages in the rem...       1
# 18   NICKIMINAJ  Ummmm lol not a chance in hell 🤣 https://t.co/...       1
# 19   NICKIMINAJ  I prefer the outro but I love the beat on the ...       1
#
#     length tweet_list
# 0       66       None
# 1      140       None
# 2      140       None
# 3      117       None
# 4       87       None
# ..     ...        ...
# 15     110       None
# 16     123       None
# 17     121       None
# 18      56       None
# 19     140       None
#
# [767 rows x 5 columns]

# %%
tweets['tweet_list'] = tweets['text'].apply(text_processing)
tweets
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-91-f7d12a087bc6> in <module>
# ----> 1 tweets['tweet_list'] = tweets['text'].apply(text_processing)
#       2 tweets
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4040             else:
#    4041                 values = self.astype(object).values
# -> 4042                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4043
#    4044         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-76-80f7c09de0c3> in text_processing(tweet)
#      15         clean_mess = [word for word in clean_s.split() if word.lower() not in stopwords.words('english')]
#      16         return clean_mess
# ---> 17     no_punc_tweet = no_user_alpha(new_tweet)
#      18
#      19     # Normalizing the words in tweets
#
# <ipython-input-76-80f7c09de0c3> in no_user_alpha(tweet)
#      10     # Removing stopwords and words with unusual symbols
#      11     def no_user_alpha(tweet):
# ---> 12         tweet_list = [ele for ele in tweets.split() if ele != 'user']
#      13         clean_tokens = [t for t in tweet_list if re.match(r'[^\W\d]*$', t)]
#      14         clean_s = ' '.join(clean_tokens)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'split'

# %%
# Clean up text
def text_processing(tweet):
    
    # Generating the list of words in the tweet (hastags and other punctuations removed)
    def form_sentence(tweet):
        tweet_blob = TextBlob(tweet)
        return ' '.join(tweet_blob.words)
    new_tweet = form_sentence(tweet)
    
    # Removing stopwords and words with unusual symbols
    def no_user_alpha(tweet):
        tweet_list = [ele for ele in tweet.split() if ele != 'user']
        clean_tokens = [t for t in tweet_list if re.match(r'[^\W\d]*$', t)]
        clean_s = ' '.join(clean_tokens)
        clean_mess = [word for word in clean_s.split() if word.lower() not in stopwords.words('english')]
        return clean_mess
    no_punc_tweet = no_user_alpha(new_tweet)
    
    # Normalizing the words in tweets 
    def normalization(tweet_list):
        lem = WordNetLemmatizer()
        normalized_tweet = []
        for word in tweet_list:
            normalized_text = lem.lemmatize(word,'v')
            normalized_tweet.append(normalized_text)
        return normalized_tweet
    
        return normalization(no_punc_tweet)

# %%
tweets['tweet_list'] = tweets['text'].apply(text_processing)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-a09c71a142c9> in <module>
# ----> 1 tweets['tweet_list'] = tweets['text'].apply(text_processing)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4040             else:
#    4041                 values = self.astype(object).values
# -> 4042                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4043
#    4044         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-76-80f7c09de0c3> in text_processing(tweet)
#      15         clean_mess = [word for word in clean_s.split() if word.lower() not in stopwords.words('english')]
#      16         return clean_mess
# ---> 17     no_punc_tweet = no_user_alpha(new_tweet)
#      18
#      19     # Normalizing the words in tweets
#
# <ipython-input-76-80f7c09de0c3> in no_user_alpha(tweet)
#      10     # Removing stopwords and words with unusual symbols
#      11     def no_user_alpha(tweet):
# ---> 12         tweet_list = [ele for ele in tweets.split() if ele != 'user']
#      13         clean_tokens = [t for t in tweet_list if re.match(r'[^\W\d]*$', t)]
#      14         clean_s = ' '.join(clean_tokens)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'split'

# %%
tweets
# Out:
#            user                                               text  gender  \
# 0   BarackObama  My statement on the death of George Floyd: htt...       0
# 1   BarackObama  If you believe in a more just, more generous, ...       0
# 2   BarackObama  On Memorial Day, we honor those who gave all f...       0
# 3   BarackObama  And here’s more on the approach Sweden has tak...       0
# 4   BarackObama  South Korea has focused on testing to guard ag...       0
# ..          ...                                                ...     ...
# 15   NICKIMINAJ  That real ass ain’t keep yo n*gga hooooome. No...       1
# 16   NICKIMINAJ  Ummm during the quarantine? I would if they ma...       1
# 17   NICKIMINAJ  There are def a few hidden messages in the rem...       1
# 18   NICKIMINAJ  Ummmm lol not a chance in hell 🤣 https://t.co/...       1
# 19   NICKIMINAJ  I prefer the outro but I love the beat on the ...       1
#
#     length tweet_list
# 0       66       None
# 1      140       None
# 2      140       None
# 3      117       None
# 4       87       None
# ..     ...        ...
# 15     110       None
# 16     123       None
# 17     121       None
# 18      56       None
# 19     140       None
#
# [767 rows x 5 columns]

# %%
# Plot WordCloud for both genders
# Sort male words
male_words = ' '.join(text for text in tweets['clean_text'][tweets['gender']==0])

# combining the image with the dataset
Mask = np.array(Image.open(requests.get('http://clipart-library.com/image_gallery2/Twitter-PNG-Image.png', stream=True).raw))

# We use the ImageColorGenerator library from Wordcloud 
# Here we take the color of the image and impose it over our wordcloud
image_colors = ImageColorGenerator(Mask)

# Now we use the WordCloud function from the wordcloud library 
wc = WordCloud(background_color='black', height=1500, width=4000,mask=Mask).generate(male_words)

# Size of the image generated 
plt.figure(figsize=(10,20))

# Here we recolor the words from the dataset to the image's color
# recolor just recolors the default colors to the image's blue color
# interpolation is used to smooth the image generated 
plt.imshow(wc.recolor(color_func=image_colors),interpolation="hamming")

plt.axis('off')
plt.show()

# %%
# Sort female words
female_words = ' '.join(text for text in tweets['clean_text'][tweets['gender']==1])

# combining the image with the dataset
Mask = np.array(Image.open(requests.get('http://clipart-library.com/image_gallery2/Twitter-PNG-Image.png', stream=True).raw))

# We use the ImageColorGenerator library from Wordcloud 
# Here we take the color of the image and impose it over our wordcloud
image_colors = ImageColorGenerator(Mask)

# Now we use the WordCloud function from the wordcloud library 
wc = WordCloud(background_color='black', height=1500, width=4000,mask=Mask).generate(female_words)

# Size of the image generated 
plt.figure(figsize=(10,20))

# Here we recolor the words from the dataset to the image's color
# recolor just recolors the default colors to the image's blue color
# interpolation is used to smooth the image generated 
plt.imshow(wc.recolor(color_func=image_colors),interpolation="hamming")

plt.axis('off')
plt.show()

# %% [markdown]
# # Recommender System for Diversity Personalization

# %%
# Import libraries
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import os
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %% [markdown]
# ### Data analysis

# %%
# Load book data from csv
books = pd.read_csv('../data/books.csv')
books
# Out:
#          id  book_id  best_book_id   work_id  books_count        isbn  \
# 0         1  2767052       2767052   2792775          272   439023483
# 1         2        3             3   4640799          491   439554934
# 2         3    41865         41865   3212258          226   316015849
# 3         4     2657          2657   3275794          487    61120081
# 4         5     4671          4671    245494         1356   743273567
# ...     ...      ...           ...       ...          ...         ...
# 9995   9996  7130616       7130616   7392860           19   441019455
# 9996   9997   208324        208324   1084709           19  067973371X
# 9997   9998    77431         77431   2393986           60  039330762X
# 9998   9999  8565083       8565083  13433613            7    61711527
# 9999  10000     8914          8914     11817           31   375700455
#
#             isbn13                      authors  original_publication_year  \
# 0     9.780439e+12              Suzanne Collins                     2008.0
# 1     9.780440e+12  J.K. Rowling, Mary GrandPré                     1997.0
# 2     9.780316e+12              Stephenie Meyer                     2005.0
# 3     9.780061e+12                   Harper Lee                     1960.0
# 4     9.780743e+12          F. Scott Fitzgerald                     1925.0
# ...            ...                          ...                        ...
# 9995  9.780441e+12                Ilona Andrews                     2010.0
# 9996  9.780680e+12               Robert A. Caro                     1990.0
# 9997  9.780393e+12              Patrick O'Brian                     1977.0
# 9998  9.780062e+12              Peggy Orenstein                     2011.0
# 9999  9.780376e+12                  John Keegan                     1998.0
#
#                                          original_title  ... ratings_count  \
# 0                                      The Hunger Games  ...       4780653
# 1              Harry Potter and the Philosopher's Stone  ...       4602479
# 2                                              Twilight  ...       3866839
# 3                                 To Kill a Mockingbird  ...       3198671
# 4                                      The Great Gatsby  ...       2683664
# ...                                                 ...  ...           ...
# 9995                                         Bayou Moon  ...         17204
# 9996                                   Means of Ascent   ...         12582
# 9997                              The Mauritius Command  ...          9421
# 9998  Cinderella Ate My Daughter: Dispatches from th...  ...         11279
# 9999                                The First World War  ...          9162
#
#      work_ratings_count  work_text_reviews_count  ratings_1  ratings_2  \
# 0               4942365                   155254      66715     127936
# 1               4800065                    75867      75504     101676
# 2               3916824                    95009     456191     436802
# 3               3340896                    72586      60427     117415
# 4               2773745                    51992      86236     197621
# ...                 ...                      ...        ...        ...
# 9995              18856                     1180        105        575
# 9996              12952                      395        303        551
# 9997              10733                      374         11        111
# 9998              11994                     1988        275       1002
# 9999               9700                      364        117        345
#
#       ratings_3  ratings_4  ratings_5  \
# 0        560092    1481305    2706317
# 1        455024    1156318    3011543
# 2        793319     875073    1355439
# 3        446835    1001952    1714267
# 4        606158     936012     947718
# ...         ...        ...        ...
# 9995       3538       7860       6778
# 9996       1737       3389       6972
# 9997       1191       4240       5180
# 9998       3765       4577       2375
# 9999       2031       4138       3069
#
#                                               image_url  \
# 0     https://images.gr-assets.com/books/1447303603m...
# 1     https://images.gr-assets.com/books/1474154022m...
# 2     https://images.gr-assets.com/books/1361039443m...
# 3     https://images.gr-assets.com/books/1361975680m...
# 4     https://images.gr-assets.com/books/1490528560m...
# ...                                                 ...
# 9995  https://images.gr-assets.com/books/1307445460m...
# 9996  https://s.gr-assets.com/assets/nophoto/book/11...
# 9997  https://images.gr-assets.com/books/1455373531m...
# 9998  https://images.gr-assets.com/books/1279214118m...
# 9999  https://images.gr-assets.com/books/1403194704m...
#
#                                         small_image_url
# 0     https://images.gr-assets.com/books/1447303603s...
# 1     https://images.gr-assets.com/books/1474154022s...
# 2     https://images.gr-assets.com/books/1361039443s...
# 3     https://images.gr-assets.com/books/1361975680s...
# 4     https://images.gr-assets.com/books/1490528560s...
# ...                                                 ...
# 9995  https://images.gr-assets.com/books/1307445460s...
# 9996  https://s.gr-assets.com/assets/nophoto/book/50...
# 9997  https://images.gr-assets.com/books/1455373531s...
# 9998  https://images.gr-assets.com/books/1279214118s...
# 9999  https://images.gr-assets.com/books/1403194704s...
#
# [10000 rows x 23 columns]

# %%
books.columns
# Out:
# Index(['id', 'book_id', 'best_book_id', 'work_id', 'books_count', 'isbn',
#        'isbn13', 'authors', 'original_publication_year', 'original_title',
#        'title', 'language_code', 'average_rating', 'ratings_count',
#        'work_ratings_count', 'work_text_reviews_count', 'ratings_1',
#        'ratings_2', 'ratings_3', 'ratings_4', 'ratings_5', 'image_url',
#        'small_image_url'],
#       dtype='object')

# %%
# books = books.drop(columns=['isbn', 'isbn13', 'image_url', 'small_image_url'])
# books

# %%
# Load ratings data from csv
ratings = pd.read_csv('../data/ratings.csv')
ratings
# Out:
#         book_id  user_id  rating
# 0             1      314       5
# 1             1      439       3
# 2             1      588       5
# 3             1     1169       4
# 4             1     1185       4
# ...         ...      ...     ...
# 981751    10000    48386       5
# 981752    10000    49007       4
# 981753    10000    49383       5
# 981754    10000    50124       5
# 981755    10000    51328       1
#
# [981756 rows x 3 columns]

# %%
# Load book_tags data from csv
book_tags = pd.read_csv('../data/book_tags.csv')
book_tags
# Out:
#         goodreads_book_id  tag_id   count
# 0                       1   30574  167697
# 1                       1   11305   37174
# 2                       1   11557   34173
# 3                       1    8717   12986
# 4                       1   33114   12716
# ...                   ...     ...     ...
# 999907           33288638   21303       7
# 999908           33288638   17271       7
# 999909           33288638    1126       7
# 999910           33288638   11478       7
# 999911           33288638   27939       7
#
# [999912 rows x 3 columns]

# %%
# Load tag data from csv
tags = pd.read_csv('../data/tags.csv')
tags
# Out:
#        tag_id    tag_name
# 0           0           -
# 1           1        --1-
# 2           2       --10-
# 3           3       --12-
# 4           4      --122-
# ...       ...         ...
# 34247   34247   Ｃhildrens
# 34248   34248   Ｆａｖｏｒｉｔｅｓ
# 34249   34249       Ｍａｎｇａ
# 34250   34250      ＳＥＲＩＥＳ
# 34251   34251  ｆａｖｏｕｒｉｔｅｓ
#
# [34252 rows x 2 columns]

# %%
# Merge book_tags and tags 
tags_join = pd.merge(book_tags, tags, left_on='tag_id', right_on='tag_id', how='inner')
tags_join
# Out:
#         goodreads_book_id  tag_id   count     tag_name
# 0                       1   30574  167697      to-read
# 1                       2   30574   24549      to-read
# 2                       3   30574  496107      to-read
# 3                       5   30574   11909      to-read
# 4                       6   30574     298      to-read
# ...                   ...     ...     ...          ...
# 999907           31538635   14690       6     hogwarts
# 999908           32848471   16149      21     jan-2017
# 999909           33288638   27821       9   single-mom
# 999910           33288638   11478       7  fave-author
# 999911           33288638   27939       7     slowburn
#
# [999912 rows x 4 columns]

# %%
# Sort by book
tags_join.sort_values(by=['goodreads_book_id'])
# Out:
#         goodreads_book_id  tag_id   count            tag_name
# 0                       1   30574  167697             to-read
# 258362                  1   33165     338               youth
# 250046                  1   17213     347              kindle
# 246919                  1   27535     348  shelfari-favorites
# 245888                  1   16799     351            juvenile
# ...                   ...     ...     ...                 ...
# 918363           33288638    2541       9              angsty
# 956326           33288638    1126       7        5-star-reads
# 358501           33288638   18680      11               loved
# 954279           33288638   29125      10       sweet-romance
# 999911           33288638   27939       7            slowburn
#
# [999912 rows x 4 columns]

# %%
# Load to_read data from csv. This shows which book a user has tagged as 'to read'.
to_read = pd.read_csv('../data/to_read.csv')
to_read
# Out:
#         user_id  book_id
# 0             1      112
# 1             1      235
# 2             1      533
# 3             1     1198
# 4             1     1874
# ...         ...      ...
# 912700    53424     4716
# 912701    53424     4844
# 912702    53424     5907
# 912703    53424     7569
# 912704    53424     8859
#
# [912705 rows x 2 columns]

# %%
# Merge tags_join and books
books_with_tags = pd.merge(books, tags_join, left_on='book_id', right_on='goodreads_book_id', how='inner')
books_with_tags
# Out:
#            id  book_id  best_book_id  work_id  books_count       isbn  \
# 0           1  2767052       2767052  2792775          272  439023483
# 1           1  2767052       2767052  2792775          272  439023483
# 2           1  2767052       2767052  2792775          272  439023483
# 3           1  2767052       2767052  2792775          272  439023483
# 4           1  2767052       2767052  2792775          272  439023483
# ...       ...      ...           ...      ...          ...        ...
# 999907  10000     8914          8914    11817           31  375700455
# 999908  10000     8914          8914    11817           31  375700455
# 999909  10000     8914          8914    11817           31  375700455
# 999910  10000     8914          8914    11817           31  375700455
# 999911  10000     8914          8914    11817           31  375700455
#
#               isbn13          authors  original_publication_year  \
# 0       9.780439e+12  Suzanne Collins                     2008.0
# 1       9.780439e+12  Suzanne Collins                     2008.0
# 2       9.780439e+12  Suzanne Collins                     2008.0
# 3       9.780439e+12  Suzanne Collins                     2008.0
# 4       9.780439e+12  Suzanne Collins                     2008.0
# ...              ...              ...                        ...
# 999907  9.780376e+12      John Keegan                     1998.0
# 999908  9.780376e+12      John Keegan                     1998.0
# 999909  9.780376e+12      John Keegan                     1998.0
# 999910  9.780376e+12      John Keegan                     1998.0
# 999911  9.780376e+12      John Keegan                     1998.0
#
#              original_title  ... ratings_2 ratings_3  ratings_4  ratings_5  \
# 0          The Hunger Games  ...    127936    560092    1481305    2706317
# 1          The Hunger Games  ...    127936    560092    1481305    2706317
# 2          The Hunger Games  ...    127936    560092    1481305    2706317
# 3          The Hunger Games  ...    127936    560092    1481305    2706317
# 4          The Hunger Games  ...    127936    560092    1481305    2706317
# ...                     ...  ...       ...       ...        ...        ...
# 999907  The First World War  ...       345      2031       4138       3069
# 999908  The First World War  ...       345      2031       4138       3069
# 999909  The First World War  ...       345      2031       4138       3069
# 999910  The First World War  ...       345      2031       4138       3069
# 999911  The First World War  ...       345      2031       4138       3069
#
#                                                 image_url  \
# 0       https://images.gr-assets.com/books/1447303603m...
# 1       https://images.gr-assets.com/books/1447303603m...
# 2       https://images.gr-assets.com/books/1447303603m...
# 3       https://images.gr-assets.com/books/1447303603m...
# 4       https://images.gr-assets.com/books/1447303603m...
# ...                                                   ...
# 999907  https://images.gr-assets.com/books/1403194704m...
# 999908  https://images.gr-assets.com/books/1403194704m...
# 999909  https://images.gr-assets.com/books/1403194704m...
# 999910  https://images.gr-assets.com/books/1403194704m...
# 999911  https://images.gr-assets.com/books/1403194704m...
#
#                                           small_image_url  goodreads_book_id  \
# 0       https://images.gr-assets.com/books/1447303603s...            2767052
# 1       https://images.gr-assets.com/books/1447303603s...            2767052
# 2       https://images.gr-assets.com/books/1447303603s...            2767052
# 3       https://images.gr-assets.com/books/1447303603s...            2767052
# 4       https://images.gr-assets.com/books/1447303603s...            2767052
# ...                                                   ...                ...
# 999907  https://images.gr-assets.com/books/1403194704s...               8914
# 999908  https://images.gr-assets.com/books/1403194704s...               8914
# 999909  https://images.gr-assets.com/books/1403194704s...               8914
# 999910  https://images.gr-assets.com/books/1403194704s...               8914
# 999911  https://images.gr-assets.com/books/1403194704s...               8914
#
#         tag_id  count                 tag_name
# 0        30574  11314                  to-read
# 1        11305  10836                  fantasy
# 2        11557  50755                favorites
# 3         8717  35418        currently-reading
# 4        33114  25968              young-adult
# ...        ...    ...                      ...
# 999907   16529      4              john-keegan
# 999908   32805      3                world-war
# 999909   32156      3                  war-ww1
# 999910   20285      3  modern-european-history
# 999911   32915      3              wwi-general
#
# [999912 rows x 27 columns]

# %%
# Display non-truncated columns
# pd.set_option('display.max_colwidth', -1)

# %%
# Store tags into the same book id row
temp_df = books_with_tags.groupby('book_id')['tag_name'].apply(' '.join).reset_index()
temp_df.head(5)
# Out:
#    book_id                                           tag_name
# 0        1  to-read fantasy favorites currently-reading yo...
# 1        2  to-read fantasy favorites currently-reading yo...
# 2        3  to-read fantasy favorites currently-reading yo...
# 3        5  to-read fantasy favorites currently-reading yo...
# 4        6  to-read fantasy young-adult fiction harry-pott...

# %%
# Merge tag_names back into books
books = pd.merge(books, temp_df, left_on='book_id', right_on='book_id', how='inner')
books.head(5)
# Out:
#    id  book_id  best_book_id  work_id  books_count       isbn        isbn13  \
# 0   1  2767052       2767052  2792775          272  439023483  9.780439e+12
# 1   2        3             3  4640799          491  439554934  9.780440e+12
# 2   3    41865         41865  3212258          226  316015849  9.780316e+12
# 3   4     2657          2657  3275794          487   61120081  9.780061e+12
# 4   5     4671          4671   245494         1356  743273567  9.780743e+12
#
#                        authors  original_publication_year  \
# 0              Suzanne Collins                     2008.0
# 1  J.K. Rowling, Mary GrandPré                     1997.0
# 2              Stephenie Meyer                     2005.0
# 3                   Harper Lee                     1960.0
# 4          F. Scott Fitzgerald                     1925.0
#
#                              original_title  ... work_ratings_count  \
# 0                          The Hunger Games  ...            4942365
# 1  Harry Potter and the Philosopher's Stone  ...            4800065
# 2                                  Twilight  ...            3916824
# 3                     To Kill a Mockingbird  ...            3340896
# 4                          The Great Gatsby  ...            2773745
#
#   work_text_reviews_count  ratings_1  ratings_2  ratings_3  ratings_4  \
# 0                  155254      66715     127936     560092    1481305
# 1                   75867      75504     101676     455024    1156318
# 2                   95009     456191     436802     793319     875073
# 3                   72586      60427     117415     446835    1001952
# 4                   51992      86236     197621     606158     936012
#
#    ratings_5                                          image_url  \
# 0    2706317  https://images.gr-assets.com/books/1447303603m...
# 1    3011543  https://images.gr-assets.com/books/1474154022m...
# 2    1355439  https://images.gr-assets.com/books/1361039443m...
# 3    1714267  https://images.gr-assets.com/books/1361975680m...
# 4     947718  https://images.gr-assets.com/books/1490528560m...
#
#                                      small_image_url  \
# 0  https://images.gr-assets.com/books/1447303603s...
# 1  https://images.gr-assets.com/books/1474154022s...
# 2  https://images.gr-assets.com/books/1361039443s...
# 3  https://images.gr-assets.com/books/1361975680s...
# 4  https://images.gr-assets.com/books/1490528560s...
#
#                                             tag_name
# 0  to-read fantasy favorites currently-reading yo...
# 1  to-read fantasy favorites currently-reading yo...
# 2  to-read fantasy favorites currently-reading yo...
# 3  to-read favorites currently-reading young-adul...
# 4  to-read favorites currently-reading young-adul...
#
# [5 rows x 24 columns]

# %%
books['tag_name']
# Out:
# 0       to-read fantasy favorites currently-reading yo...
# 1       to-read fantasy favorites currently-reading yo...
# 2       to-read fantasy favorites currently-reading yo...
# 3       to-read favorites currently-reading young-adul...
# 4       to-read favorites currently-reading young-adul...
#                               ...
# 9995    to-read fantasy favorites currently-reading fi...
# 9996    to-read favorites currently-reading books-i-ow...
# 9997    to-read favorites currently-reading fiction bo...
# 9998    to-read favorites currently-reading books-i-ow...
# 9999    to-read favorites currently-reading books-i-ow...
# Name: tag_name, Length: 10000, dtype: object

# %% [markdown]
# ### Feature engineering and machine learning algorithm
#
# * Use TfidVectorizer to transform text to feature vectors
# * Use Cosine Similarity to calculate numeric values that denote the similarity between books

# %%
tf = TfidfVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(books['tag_name'])
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
cosine_sim
# Out:
# array([[1.        , 0.23560979, 0.28324674, ..., 0.05084198, 0.07947133,
#         0.01691533],
#        [0.23560979, 1.        , 0.22459026, ..., 0.0530554 , 0.07126569,
#         0.02330787],
#        [0.28324674, 0.22459026, 1.        , ..., 0.03356699, 0.04251551,
#         0.01473002],
#        ...,
#        [0.05084198, 0.0530554 , 0.03356699, ..., 1.        , 0.0262993 ,
#         0.07240815],
#        [0.07947133, 0.07126569, 0.04251551, ..., 0.0262993 , 1.        ,
#         0.07219924],
#        [0.01691533, 0.02330787, 0.01473002, ..., 0.07240815, 0.07219924,
#         1.        ]])

# %%
# Build a 1-dimensional array with book titles
titles = books['title']
tag_name = books['tag_name']
indices = pd.Series(books.index, index=books['title'])

# Function that gets book recommendations based on the cosine similarity score of book tags
def tags_recommendations(title):
    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[:] # How many results to display
    book_indices = [i[0] for i in sim_scores]
    title_df = pd.DataFrame({'title': titles.iloc[book_indices].tolist(),
                           'similarity': [i[1] for i in sim_scores],
                            'tag_name': tag_name.iloc[book_indices].tolist()},
                           index=book_indices)
    return title_df

# Function that gets book book tags and stats
def recommend_stats(target_book_title):
    
    # Get recommended books
    rec_df = tags_recommendations(target_book_title)
    
    # Get tags of the target book
    rec_book_tags = books_with_tags[books_with_tags['title'] == target_book_title]['tag_name'].to_list()
    
    # Create dictionary of tag lists by book title
    book_tag_dict = {}
    for title in rec_df['title'].tolist():
        book_tag_dict[title] = books_with_tags[books_with_tags['title'] == title]['tag_name'].to_list()
    
    # Create dictionary of tag statistics by book title
    tags_stats = {}
    for book, tags in book_tag_dict.items():
        tags_stats[book] = {}
        tags_stats[book]['total_tags'] = len(tags)
        same_tags = set(rec_book_tags).intersection(set(tags)) # Get tags in recommended book that are also in target book
        tags_stats[book]['%_common_tags'] = (len(same_tags) / len(tags)) * 100
    
    # Convert dictionary to dataframe
    tags_stats_df = pd.DataFrame.from_dict(tags_stats, orient='index').reset_index().rename(columns={'index': 'title'})
    
    # Merge tag statistics dataframe to recommended books dataframe
    all_stats_df = pd.merge(rec_df, tags_stats_df, on='title')
    return all_stats_df

# %%
# Displays all rows without truncating
# pd.set_option('display.max_rows', None)

# Display all columns without truncating
# pd.set_option('display.max_colwidth', -1)

# %%
lor_recs = recommend_stats('The Fellowship of the Ring (The Lord of the Rings, #1)')
lor_recs
# Out:
#                                                   title  similarity  \
# 0     The Fellowship of the Ring (The Lord of the Ri...    1.000000
# 1     The Return of the King (The Lord of the Rings,...    0.865246
# 2            The Two Towers (The Lord of the Rings, #2)    0.846638
# 3     The Lord of the Rings (The Lord of the Rings, ...    0.676849
# 4              The Silmarillion (Middle-Earth Universe)    0.638828
# ...                                                 ...         ...
# 9995  Maryamah Karpov: Mimpi-mimpi Lintang (Tetralog...    0.012938
# 9996                                   The Power of Art    0.012782
# 9997           Veganomicon: The Ultimate Vegan Cookbook    0.011444
# 9998                Edvard Munch: 1863-1944 (Basic Art)    0.011206
# 9999                          رحلتي من الشك إلى الإيمان    0.010575
#
#                                                tag_name  total_tags  \
# 0     to-read fantasy favorites currently-reading yo...         100
# 1     to-read fantasy favorites currently-reading yo...         100
# 2     to-read fantasy favorites currently-reading yo...         100
# 3     to-read fantasy favorites currently-reading yo...         100
# 4     to-read fantasy favorites currently-reading yo...         100
# ...                                                 ...         ...
# 9995  to-read favorites currently-reading young-adul...         100
# 9996  to-read favorites currently-reading default en...         100
# 9997  to-read favorites currently-reading books-i-ow...         100
# 9998  to-read favorites currently-reading books-i-ow...         100
# 9999  to-read favorites currently-reading owned favo...         100
#
#       %_common_tags
# 0             100.0
# 1              92.0
# 2              90.0
# 3              84.0
# 4              77.0
# ...             ...
# 9995           16.0
# 9996            8.0
# 9997           16.0
# 9998            8.0
# 9999           14.0
#
# [10000 rows x 5 columns]

# %%
lor_recs.boxplot(column=['similarity'])
plt.show()

# %%
lor_recs.boxplot(column=['%_common_tags'])
plt.show()

# %% [markdown]
# ### Reverse engineer

# %%
# Select rows with similarity values between 0.035 to 0.045 and % common tags between 20 to 25
lor_recs.loc[(lor_recs['similarity'] >= 0.037) & (lor_recs['similarity'] <= 0.040449) & (lor_recs['%_common_tags'] >= 22) & (lor_recs['%_common_tags'] <= 23)]
lor_recs_filter
# Out:
#                                                   title  similarity  \
# 6                                 The Children of Húrin    0.537546
# 7          Unfinished Tales of Númenor and Middle-Earth    0.532336
# 8     J.R.R. Tolkien 4-Book Boxed Set: The Hobbit an...    0.514953
# 9                             The Hobbit: Graphic Novel    0.486699
# 10                 Pawn of Prophecy (The Belgariad, #1)    0.424535
# ...                                                 ...         ...
# 9956                                    Ayat-Ayat Cinta    0.017322
# 9957  Food Inc.: A Participant Guide: How Industrial...    0.017257
# 9959                                             Plenty    0.017176
# 9960                      Baking: From My Home to Yours    0.017140
# 9961  Presentation Zen: Simple Ideas on Presentation...    0.017041
#
#                                                tag_name  total_tags  \
# 6     to-read fantasy favorites currently-reading yo...         100
# 7     to-read fantasy favorites currently-reading fi...         100
# 8     to-read fantasy favorites currently-reading yo...         100
# 9     to-read fantasy favorites currently-reading yo...         100
# 10    to-read fantasy favorites currently-reading yo...         100
# ...                                                 ...         ...
# 9956  to-read favorites currently-reading young-adul...         100
# 9957  to-read favorites currently-reading books-i-ow...         100
# 9959  to-read favorites currently-reading books-i-ow...         100
# 9960  to-read favorites currently-reading books-i-ow...         100
# 9961  to-read favorites currently-reading books-i-ow...         100
#
#       %_common_tags
# 6              67.0
# 7              65.0
# 8              59.0
# 9              59.0
# 10             61.0
# ...             ...
# 9956           16.0
# 9957           15.0
# 9959           15.0
# 9960           14.0
# 9961           14.0
#
# [9941 rows x 5 columns]

# %%
# Merge recommendations with ratings
recs_merge = pd.merge(books, lor_recs_filter, left_on='title', right_on='title', how='inner')

# %%
lor_recs_filter_nonfiction = recs_merge[recs_merge['tag_name_x'].str.contains("business")]
lor_recs_filter_nonfiction = lor_recs_filter_nonfiction.drop(columns=['best_book_id', 'work_id', 'isbn', 'isbn13', 'image_url', 'small_image_url', 'tag_name_y'])

# %%
# pd.reset_option('display.max_colwidth')
pd.set_option('display.max_rows', 400)
lor_recs_filter_nonfiction = lor_recs_filter_nonfiction.sort_values(by=['ratings_5'], ascending=False)
lor_recs_filter_nonfiction
# Out:
#         id   book_id  books_count  \
# 125    128  11084145          190
# 89      92      1202          124
# 124    127      2612          100
# 193    193   3228917          120
# 260    260      4865          353
# 247    247     36072          250
# 329    329   2318271          111
# 211    211     40102          116
# 255    255       662          147
# 478    472      4069          187
# 287    287      2122          154
# 412    406    627206           64
# 391    385   8520610           86
# 303    303     52529          113
# 315    315      4894          128
# 406    400     22328          143
# 454    448     56495          149
# 409    403     10534         1865
# 414    408      1842          118
# 594    582     69571          185
# 630    619  11468377          106
# 546    537  12609433           92
# 881    870      2199           40
# 691    680      1005          709
# 755    744      6708          153
# 801    790      6596           82
# 967    956      5544           97
# 485    479     28862         1654
# 730    719     76334           45
# 641    630  16071764           66
# 555    546       629          181
# 583    574     33313           78
# 404    398      1097           61
# 996    985   6463967           57
# 514    508      1869           57
# 1152  1141  13099738           33
# 2158  2139  22543496           93
# 931    920  22318578           94
# 1431  1415  10127019           47
# 1001   990   6732019           60
# 943    932     76865           63
# 1165  1154      1301           39
# 1046  1035     10884           78
# 1089  1078      1633          115
# 1080  1069   6402364           77
# 903    892  15751404           68
# 1365  1349    817791           35
# 1750  1734    139069           75
# 1400  1384     38210           94
# 1700  1684      1052          187
# 1893  1877     33514          240
# 1417  1401    615570           72
# 2079  2060  13588356           44
# 2099  2080  24453082           65
# 1983  1967     30659          768
# 1349  1333     10883           30
# 1875  1859     12543           28
# 1319  1303    347852           94
# 1202  1188    368593          106
# 1387  1371   1713426           85
# 2197  2175     16130            6
# 1289  1272      8600           38
# 1721  1705     28815          114
# 2188  2166  18050143           50
# 2055  2036   7015403           49
# 1523  1507   1134122          116
# 1168  1157    763362           86
# 1346  1330    170548           82
# 1816  1800     22590          151
# 1631  1615   6480781           60
# 2332  2310     78427           32
# 1766  1750      4866          175
# 1699  1683      1171           44
# 2008  1992    759945           90
# 1203  1189     43877          138
# 980    969      1911           83
# 9640  to-read favorites currently-reading books-i-ow...   0.020714
# 7439  to-read favorites currently-reading fiction ow...   0.060591
# 8712  to-read favorites currently-reading fiction bo...   0.037203
# 8877  to-read favorites currently-reading books-i-ow...   0.036811
# 9686  to-read favorites currently-reading books-i-ow...   0.026780
# 8482  to-read favorites currently-reading books-i-ow...   0.019552
# 9891  to-read favorites currently-reading books-i-ow...   0.037484
# 6799  to-read favorites currently-reading fiction bo...   0.045442
# 7725  to-read favorites currently-reading books-i-ow...   0.034740
# 8526  to-read favorites currently-reading fiction bo...   0.071716
# 8950  to-read favorites currently-reading books-i-ow...   0.033203
# 8994  to-read favorites currently-reading fiction bo...   0.044751
# 8262  to-read favorites currently-reading books-i-ow...   0.031823
# 7983  to-read favorites currently-reading books-i-ow...   0.048520
# 8679  to-read favorites currently-reading books-i-ow...   0.055254
# 9716  to-read favorites currently-reading books-i-ow...   0.038437
# 9696  to-read favorites currently-reading books-i-ow...   0.052451
# 9436  to-read favorites currently-reading books-i-ow...   0.043877
# 4057  to-read favorites currently-reading fiction bo...   0.101271
# 9644  to-read favorites currently-reading fiction bo...   0.057653
# 8748  to-read favorites currently-reading fiction bo...   0.041795
# 9224  to-read favorites currently-reading books-i-ow...   0.020141
# 9342  to-read currently-reading fiction books-i-own ...   0.106852
# 9682  to-read favorites currently-reading books-i-ow...   0.053945
# 8445  to-read favorites currently-reading fiction bo...   0.047628
# 8223  to-read favorites currently-reading fiction bo...   0.025470
#
#       total_tags  %_common_tags
# 125          100      30.000000
# 89           100      30.000000
# 124          100      29.000000
# 193          100      29.000000
# 260          100      30.000000
# 247          100      33.000000
# 329          100      30.000000
# 211          100      30.000000
# 255          100      45.000000
# 478          100      36.000000
# 287          100      47.000000
# 412          100      17.000000
# 391          100      21.000000
# 303          100      38.000000
# 315          100      31.000000
# 406          100      44.000000
# 454          100      26.000000
# 409          100      34.000000
# 414          100      31.000000
# 594          100      31.000000
# 630          100      26.000000
# 546          100      26.000000
# 881          100      27.000000
# 691          100      24.000000
# 755          100      34.000000
# 801          100      34.000000
# 967          100      32.000000
# 485          100      36.000000
# 730          100      34.000000
# 641          100      28.000000
# 555          100      41.000000
# 583          100      27.000000
# 404          100      22.000000
# 996          100      26.000000
# 514          100      20.000000
# 1152         100      23.000000
# 2158         100      25.000000
# 931          100      26.000000
# 1431         100      24.000000
# 1001         100      26.000000
# 943          100      27.000000
# 1165         100      29.000000
# 1046         100      31.000000
# 1089         100      31.000000
# 1080         100      27.000000
# 903          100      26.000000
# 1365         100      36.000000
# 1750         100      34.000000
# 1400         100      30.000000
# 1700         100      27.000000
# 1893         100      25.000000
# 1417         100      22.000000
# 2079         100      26.000000
# 2099         100      28.000000
# 1983         100      27.000000
# 1349         100      26.000000
# 1875         100      37.000000
# 1319         100      27.000000
# 1202         100      27.000000
# 1387         100      24.000000
# 2197         100      28.000000
# 1289         100      27.000000
# 1721         100      19.000000
# 2188         100      23.000000
# 2055         100      26.000000
# 8331         100      24.000000
# 9645         100      19.000000
# 8868         100      22.000000
# 8964         100      26.000000
# 9281         100      19.000000
# 7033         100      23.000000
# 7997         100      22.000000
# 7839          56      16.071429
# 6292         100      20.000000
# 6620         100      17.000000
# 8512         100      25.000000
# 9217         100      31.000000
# 7907         100      16.000000
# 7755         100      27.000000
# 8955         100      21.000000
# 8117         100      22.000000
# 9107         100      19.000000
# 9781         100      19.000000
# 9593         100      16.000000
# 6993         100      35.000000
# 8760         100      20.000000
# 8000         100      25.000000
# 8211         100      16.000000
# 7669         100      28.000000
# 8570         100      19.000000
# 8663         100      20.000000
# 9311         100      25.000000
# 8079         100      20.000000
# 7791         100      20.000000
# 5636         100      23.000000
# 7189         100      23.000000
# 9365         100      23.000000
# 8067         100      22.000000
# 9778         100      25.000000
# 9362         100      24.000000
# 8627         100      24.000000
# 9958         100      24.000000
# 9393         100      22.000000
# 9951         100      18.000000
# 9640         100      18.000000
# 7439         100      26.000000
# 8712         100      28.000000
# 8877         100      25.000000
# 9686         100      17.000000
# 8482         100      15.000000
# 9891         100      18.000000
# 6799         100      25.000000
# 7725         100      18.000000
# 8526         100      20.000000
# 8950         100      24.000000
# 8994         100      26.000000
# 8262         100      17.000000
# 7983         100      24.000000
# 8679         100      22.000000
# 9716         100      24.000000
# 9696         100      22.000000
# 9436         100      23.000000
# 4057         100      32.000000
# 9644         100      30.000000
# 8748         100      26.000000
# 9224         100      16.000000
# 9342         100      34.000000
# 9682         100      23.000000
# 8445         100      28.000000
# 8223         100      17.000000
#
# [381 rows x 21 columns]

# %% [markdown]
# ### Explore the book data

# %%
# Book tags for Lord of the Rings
lord_of_the_rings_tags = pd.DataFrame(books_with_tags[books_with_tags['title']=='The Fellowship of the Ring (The Lord of the Rings, #1)']['tag_name'])
lord_of_the_rings_tags
# Out:
#                      tag_name
# 1800                  to-read
# 1801                  fantasy
# 1802                favorites
# 1803        currently-reading
# 1804              young-adult
# ...                       ...
# 1895  fantasy-science-fiction
# 1896                    elves
# 1897                  tolkien
# 1898                 fantasía
# 1899    the-lord-of-the-rings
#
# [100 rows x 1 columns]

# %%
lord_of_the_rings_tags.tag_name.mode()
# Out:
# 0                               1001
# 1                         1001-books
# 2                       20th-century
# 3                            5-stars
# 4                          abandoned
# 5                              adult
# 6                      adult-fiction
# 7                          adventure
# 8                 all-time-favorites
# 9                            audible
# 10                             audio
# 11                         audiobook
# 12                        audiobooks
# 13                             books
# 14                       books-i-own
# 15                         bookshelf
# 16                           british
# 17                british-literature
# 18                         childhood
# 19                           classic
# 20                classic-literature
# 21                          classics
# 22                 currently-reading
# 23                           default
# 24                               dnf
# 25                             ebook
# 26                            ebooks
# 27                             elves
# 28                           english
# 29                              epic
# 30                      epic-fantasy
# 31                          fantasia
# 32                           fantasy
# 33                fantasy-and-sci-fi
# 34                   fantasy-fiction
# 35           fantasy-science-fiction
# 36                     fantasy-scifi
# 37                          fantasía
# 38                          favorite
# 39                    favorite-books
# 40                         favorites
# 41                         favourite
# 42                        favourites
# 43                           fiction
# 44                   fiction-fantasy
# 45                              have
# 46                      high-fantasy
# 47                      home-library
# 48                             i-own
# 49                     j-r-r-tolkien
# 50                            kindle
# 51                           library
# 52                        literature
# 53                 lord-of-the-rings
# 54                              lotr
# 55                             magic
# 56                      middle-earth
# 57                   modern-classics
# 58                             movie
# 59                            movies
# 60                          my-books
# 61                      my-bookshelf
# 62                      my-favorites
# 63                        my-library
# 64                             novel
# 65                            novels
# 66                           on-hold
# 67                       on-my-shelf
# 68                            own-it
# 69                             owned
# 70                       owned-books
# 71                         paperback
# 72                           re-read
# 73                          re-reads
# 74                      read-in-2014
# 75                      read-in-2015
# 76                      read-in-2016
# 77               read-more-than-once
# 78                            reread
# 79    rory-gilmore-reading-challenge
# 80                            sci-fi
# 81                sci-fi-and-fantasy
# 82                    sci-fi-fantasy
# 83                   science-fiction
# 84           science-fiction-fantasy
# 85                            series
# 86                        sf-fantasy
# 87                shelfari-favorites
# 88               speculative-fiction
# 89                            séries
# 90                               tbr
# 91             the-lord-of-the-rings
# 92                            to-buy
# 93                        to-re-read
# 94                           to-read
# 95                           tolkien
# 96                        unfinished
# 97                               war
# 98                                ya
# 99                       young-adult
# dtype: object

# %%
# Book tags for Zero to One
zero_to_one_tags = pd.DataFrame(books_with_tags[books_with_tags['title']=='Zero to One: Notes on Startups, or How to Build the Future']['tag_name'])
zero_to_one_tags
# Out:
#                  tag_name
# 216462            to-read
# 216463          favorites
# 216464  currently-reading
# 216465        books-i-own
# 216466              owned
# ...                   ...
# 216557          elon-musk
# 216558    entrepreneurial
# 216559          start-ups
# 216560   enterpreneurship
# 216561        skimm-reads
#
# [100 rows x 1 columns]

# %%
# Book tag for other startup book
startup_tags = pd.DataFrame(books_with_tags[books_with_tags['title']=='Founders at Work: Stories of Startups\' Early Days']['tag_name'])
startup_tags
# Out:
#                            tag_name
# 646162                      to-read
# 646163                    favorites
# 646164            currently-reading
# 646165                  books-i-own
# 646166                        owned
# ...                             ...
# 646257             enterpreneurship
# 646258             empreendedorismo
# 646259  transform-life-and-business
# 646260        recommended-by-others
# 646261                      at-work
#
# [100 rows x 1 columns]

# %%
# Check commonalities and differences within each
# False = different
# True = common
lord_of_the_rings_tags['tag_name'].isin(zero_to_one_tags['tag_name']).value_counts(normalize=True)
# Out:
# False    0.77
# True     0.23
# Name: tag_name, dtype: float64

# %%
# Check commonalities and differences within each
# False = different
# True = common
lord_of_the_rings_tags['tag_name'].isin(startup_tags['tag_name']).value_counts(normalize=True)
# Out:
# False    0.8
# True     0.2
# Name: tag_name, dtype: float64

# %%
# Concatenate the two dataframes
df_diff = pd.concat([lord_of_the_rings_tags,zero_to_one_tags]).drop_duplicates(keep=False)
pd.set_option('display.max_rows', 160)
df_diff
# Out:
#                               tag_name
# 1801                           fantasy
# 1804                       young-adult
# 1805                           fiction
# 1808                                ya
# 1809                            series
# 1811                             magic
# 1812                       owned-books
# 1814                         adventure
# 216553       business-entrepreneurship
# 216554                       before-30
# 216555                        listened
# 216556                         next-up
# 216557                       elon-musk
# 216558                 entrepreneurial
# 216559                       start-ups
# 216560                enterpreneurship
# 216561                     skimm-reads

# %%
df_diff = pd.concat([lord_of_the_rings_tags, zero_to_one_tags]).loc[lord_of_the_rings_tags.index.symmetric_difference(zero_to_one_tags.index)]
df_diff
# Out:
#                  tag_name
# 1800              to-read
# 1801              fantasy
# 1802            favorites
# 1803    currently-reading
# 1804          young-adult
# ...                   ...
# 216557          elon-musk
# 216558    entrepreneurial
# 216559          start-ups
# 216560   enterpreneurship
# 216561        skimm-reads
#
# [200 rows x 1 columns]

# %% [markdown]
# ### Find opposite of a word

# %%
from nltk.corpus import wordnet 
syns = wordnet.synsets("program") 
print(syns[0].name())
# Out:
# plan.n.01

# %%
import nltk 
from nltk.corpus import wordnet

# %%
synonyms = [] 
antonyms = [] 
  
for syn in wordnet.synsets("business"): 
    for l in syn.lemmas(): 
        synonyms.append(l.name()) 
        if l.antonyms(): 
            antonyms.append(l.antonyms()[0].name()) 
  
print(set(antonyms))
# Out:
# set()

# %%
#Checking antonym for the word "increase"
from nltk.corpus import wordnet
antonyms = []
for syn in wordnet.synsets("book"):
    for lm in syn.lemmas():
        if lm.antonyms():
            antonyms.append(lm.antonyms()[0].name()) #adding into antonyms
print(set(antonyms))
# Out:
# set()

# %% [markdown]
# ### Filter for opposite of most frequent tag

# %%
lor_recs_filter_business = lor_recs.loc[lor_recs['tag_name'].str.contains("nonfiction")]
lor_recs_filter_business
# Out:
#                                                   title  similarity  \
# 55                   The Complete Guide to Middle-Earth    0.364751
# 211          The Lord of the Rings: Weapons and Warfare    0.316916
# 328   The Lord of the Rings: The Art of The Fellowsh...    0.290414
# 419                                             Contact    0.274136
# 478    The History of the Hobbit, Part One: Mr. Baggins    0.265286
# ...                                                 ...         ...
# 9995  Maryamah Karpov: Mimpi-mimpi Lintang (Tetralog...    0.012938
# 9996                                   The Power of Art    0.012782
# 9997           Veganomicon: The Ultimate Vegan Cookbook    0.011444
# 9998                Edvard Munch: 1863-1944 (Basic Art)    0.011206
# 9999                          رحلتي من الشك إلى الإيمان    0.010575
#
#                                                tag_name  total_tags  \
# 55    to-read fantasy favorites currently-reading yo...         100
# 211   to-read fantasy favorites currently-reading fi...         100
# 328   to-read fantasy favorites currently-reading fi...         100
# 419   to-read fantasy favorites currently-reading fi...         100
# 478   to-read fantasy favorites currently-reading yo...         100
# ...                                                 ...         ...
# 9995  to-read favorites currently-reading young-adul...         100
# 9996  to-read favorites currently-reading default en...         100
# 9997  to-read favorites currently-reading books-i-ow...         100
# 9998  to-read favorites currently-reading books-i-ow...         100
# 9999  to-read favorites currently-reading owned favo...         100
#
#       %_common_tags
# 55             40.0
# 211            33.0
# 328            32.0
# 419            53.0
# 478            31.0
# ...             ...
# 9995           16.0
# 9996            8.0
# 9997           16.0
# 9998            8.0
# 9999           14.0
#
# [1844 rows x 5 columns]

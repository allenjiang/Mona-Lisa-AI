# %% [markdown]
# # Recommender System for Diversity Personalization

# %%
# Import libraries
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import os
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %% [markdown]
# ### Data analysis

# %%
# Load book data from csv
books = pd.read_csv('../data/books.csv')
books
# Out:
#          id  book_id  best_book_id   work_id  books_count        isbn  \
# 0         1  2767052       2767052   2792775          272   439023483
# 1         2        3             3   4640799          491   439554934
# 2         3    41865         41865   3212258          226   316015849
# 3         4     2657          2657   3275794          487    61120081
# 4         5     4671          4671    245494         1356   743273567
# ...     ...      ...           ...       ...          ...         ...
# 9995   9996  7130616       7130616   7392860           19   441019455
# 9996   9997   208324        208324   1084709           19  067973371X
# 9997   9998    77431         77431   2393986           60  039330762X
# 9998   9999  8565083       8565083  13433613            7    61711527
# 9999  10000     8914          8914     11817           31   375700455
#
#             isbn13                      authors  original_publication_year  \
# 0     9.780439e+12              Suzanne Collins                     2008.0
# 1     9.780440e+12  J.K. Rowling, Mary GrandPré                     1997.0
# 2     9.780316e+12              Stephenie Meyer                     2005.0
# 3     9.780061e+12                   Harper Lee                     1960.0
# 4     9.780743e+12          F. Scott Fitzgerald                     1925.0
# ...            ...                          ...                        ...
# 9995  9.780441e+12                Ilona Andrews                     2010.0
# 9996  9.780680e+12               Robert A. Caro                     1990.0
# 9997  9.780393e+12              Patrick O'Brian                     1977.0
# 9998  9.780062e+12              Peggy Orenstein                     2011.0
# 9999  9.780376e+12                  John Keegan                     1998.0
#
#                                          original_title  ... ratings_count  \
# 0                                      The Hunger Games  ...       4780653
# 1              Harry Potter and the Philosopher's Stone  ...       4602479
# 2                                              Twilight  ...       3866839
# 3                                 To Kill a Mockingbird  ...       3198671
# 4                                      The Great Gatsby  ...       2683664
# ...                                                 ...  ...           ...
# 9995                                         Bayou Moon  ...         17204
# 9996                                   Means of Ascent   ...         12582
# 9997                              The Mauritius Command  ...          9421
# 9998  Cinderella Ate My Daughter: Dispatches from th...  ...         11279
# 9999                                The First World War  ...          9162
#
#      work_ratings_count  work_text_reviews_count  ratings_1  ratings_2  \
# 0               4942365                   155254      66715     127936
# 1               4800065                    75867      75504     101676
# 2               3916824                    95009     456191     436802
# 3               3340896                    72586      60427     117415
# 4               2773745                    51992      86236     197621
# ...                 ...                      ...        ...        ...
# 9995              18856                     1180        105        575
# 9996              12952                      395        303        551
# 9997              10733                      374         11        111
# 9998              11994                     1988        275       1002
# 9999               9700                      364        117        345
#
#       ratings_3  ratings_4  ratings_5  \
# 0        560092    1481305    2706317
# 1        455024    1156318    3011543
# 2        793319     875073    1355439
# 3        446835    1001952    1714267
# 4        606158     936012     947718
# ...         ...        ...        ...
# 9995       3538       7860       6778
# 9996       1737       3389       6972
# 9997       1191       4240       5180
# 9998       3765       4577       2375
# 9999       2031       4138       3069
#
#                                               image_url  \
# 0     https://images.gr-assets.com/books/1447303603m...
# 1     https://images.gr-assets.com/books/1474154022m...
# 2     https://images.gr-assets.com/books/1361039443m...
# 3     https://images.gr-assets.com/books/1361975680m...
# 4     https://images.gr-assets.com/books/1490528560m...
# ...                                                 ...
# 9995  https://images.gr-assets.com/books/1307445460m...
# 9996  https://s.gr-assets.com/assets/nophoto/book/11...
# 9997  https://images.gr-assets.com/books/1455373531m...
# 9998  https://images.gr-assets.com/books/1279214118m...
# 9999  https://images.gr-assets.com/books/1403194704m...
#
#                                         small_image_url
# 0     https://images.gr-assets.com/books/1447303603s...
# 1     https://images.gr-assets.com/books/1474154022s...
# 2     https://images.gr-assets.com/books/1361039443s...
# 3     https://images.gr-assets.com/books/1361975680s...
# 4     https://images.gr-assets.com/books/1490528560s...
# ...                                                 ...
# 9995  https://images.gr-assets.com/books/1307445460s...
# 9996  https://s.gr-assets.com/assets/nophoto/book/50...
# 9997  https://images.gr-assets.com/books/1455373531s...
# 9998  https://images.gr-assets.com/books/1279214118s...
# 9999  https://images.gr-assets.com/books/1403194704s...
#
# [10000 rows x 23 columns]

# %%
books.columns
# Out:
# Index(['id', 'book_id', 'best_book_id', 'work_id', 'books_count', 'isbn',
#        'isbn13', 'authors', 'original_publication_year', 'original_title',
#        'title', 'language_code', 'average_rating', 'ratings_count',
#        'work_ratings_count', 'work_text_reviews_count', 'ratings_1',
#        'ratings_2', 'ratings_3', 'ratings_4', 'ratings_5', 'image_url',
#        'small_image_url'],
#       dtype='object')

# %%
# books = books.drop(columns=['isbn', 'isbn13', 'image_url', 'small_image_url'])
# books

# %%
# Load ratings data from csv
ratings = pd.read_csv('../data/ratings.csv')
ratings
# Out:
#         book_id  user_id  rating
# 0             1      314       5
# 1             1      439       3
# 2             1      588       5
# 3             1     1169       4
# 4             1     1185       4
# ...         ...      ...     ...
# 981751    10000    48386       5
# 981752    10000    49007       4
# 981753    10000    49383       5
# 981754    10000    50124       5
# 981755    10000    51328       1
#
# [981756 rows x 3 columns]

# %%
# Load book_tags data from csv
book_tags = pd.read_csv('../data/book_tags.csv')
book_tags
# Out:
#         goodreads_book_id  tag_id   count
# 0                       1   30574  167697
# 1                       1   11305   37174
# 2                       1   11557   34173
# 3                       1    8717   12986
# 4                       1   33114   12716
# ...                   ...     ...     ...
# 999907           33288638   21303       7
# 999908           33288638   17271       7
# 999909           33288638    1126       7
# 999910           33288638   11478       7
# 999911           33288638   27939       7
#
# [999912 rows x 3 columns]

# %%
# Load tag data from csv
tags = pd.read_csv('../data/tags.csv')
tags
# Out:
#        tag_id    tag_name
# 0           0           -
# 1           1        --1-
# 2           2       --10-
# 3           3       --12-
# 4           4      --122-
# ...       ...         ...
# 34247   34247   Ｃhildrens
# 34248   34248   Ｆａｖｏｒｉｔｅｓ
# 34249   34249       Ｍａｎｇａ
# 34250   34250      ＳＥＲＩＥＳ
# 34251   34251  ｆａｖｏｕｒｉｔｅｓ
#
# [34252 rows x 2 columns]

# %%
# Merge book_tags and tags 
tags_join = pd.merge(book_tags, tags, left_on='tag_id', right_on='tag_id', how='inner')
tags_join
# Out:
#         goodreads_book_id  tag_id   count     tag_name
# 0                       1   30574  167697      to-read
# 1                       2   30574   24549      to-read
# 2                       3   30574  496107      to-read
# 3                       5   30574   11909      to-read
# 4                       6   30574     298      to-read
# ...                   ...     ...     ...          ...
# 999907           31538635   14690       6     hogwarts
# 999908           32848471   16149      21     jan-2017
# 999909           33288638   27821       9   single-mom
# 999910           33288638   11478       7  fave-author
# 999911           33288638   27939       7     slowburn
#
# [999912 rows x 4 columns]

# %%
# Sort by book
tags_join.sort_values(by=['goodreads_book_id'])
# Out:
#         goodreads_book_id  tag_id   count            tag_name
# 0                       1   30574  167697             to-read
# 258362                  1   33165     338               youth
# 250046                  1   17213     347              kindle
# 246919                  1   27535     348  shelfari-favorites
# 245888                  1   16799     351            juvenile
# ...                   ...     ...     ...                 ...
# 918363           33288638    2541       9              angsty
# 956326           33288638    1126       7        5-star-reads
# 358501           33288638   18680      11               loved
# 954279           33288638   29125      10       sweet-romance
# 999911           33288638   27939       7            slowburn
#
# [999912 rows x 4 columns]

# %%
# Load to_read data from csv. This shows which book a user has tagged as 'to read'.
to_read = pd.read_csv('../data/to_read.csv')
to_read
# Out:
#         user_id  book_id
# 0             1      112
# 1             1      235
# 2             1      533
# 3             1     1198
# 4             1     1874
# ...         ...      ...
# 912700    53424     4716
# 912701    53424     4844
# 912702    53424     5907
# 912703    53424     7569
# 912704    53424     8859
#
# [912705 rows x 2 columns]

# %%
# Merge tags_join and books
books_with_tags = pd.merge(books, tags_join, left_on='book_id', right_on='goodreads_book_id', how='inner')
books_with_tags
# Out:
#            id  book_id  best_book_id  work_id  books_count       isbn  \
# 0           1  2767052       2767052  2792775          272  439023483
# 1           1  2767052       2767052  2792775          272  439023483
# 2           1  2767052       2767052  2792775          272  439023483
# 3           1  2767052       2767052  2792775          272  439023483
# 4           1  2767052       2767052  2792775          272  439023483
# ...       ...      ...           ...      ...          ...        ...
# 999907  10000     8914          8914    11817           31  375700455
# 999908  10000     8914          8914    11817           31  375700455
# 999909  10000     8914          8914    11817           31  375700455
# 999910  10000     8914          8914    11817           31  375700455
# 999911  10000     8914          8914    11817           31  375700455
#
#               isbn13          authors  original_publication_year  \
# 0       9.780439e+12  Suzanne Collins                     2008.0
# 1       9.780439e+12  Suzanne Collins                     2008.0
# 2       9.780439e+12  Suzanne Collins                     2008.0
# 3       9.780439e+12  Suzanne Collins                     2008.0
# 4       9.780439e+12  Suzanne Collins                     2008.0
# ...              ...              ...                        ...
# 999907  9.780376e+12      John Keegan                     1998.0
# 999908  9.780376e+12      John Keegan                     1998.0
# 999909  9.780376e+12      John Keegan                     1998.0
# 999910  9.780376e+12      John Keegan                     1998.0
# 999911  9.780376e+12      John Keegan                     1998.0
#
#              original_title  ... ratings_2 ratings_3  ratings_4  ratings_5  \
# 0          The Hunger Games  ...    127936    560092    1481305    2706317
# 1          The Hunger Games  ...    127936    560092    1481305    2706317
# 2          The Hunger Games  ...    127936    560092    1481305    2706317
# 3          The Hunger Games  ...    127936    560092    1481305    2706317
# 4          The Hunger Games  ...    127936    560092    1481305    2706317
# ...                     ...  ...       ...       ...        ...        ...
# 999907  The First World War  ...       345      2031       4138       3069
# 999908  The First World War  ...       345      2031       4138       3069
# 999909  The First World War  ...       345      2031       4138       3069
# 999910  The First World War  ...       345      2031       4138       3069
# 999911  The First World War  ...       345      2031       4138       3069
#
#                                                 image_url  \
# 0       https://images.gr-assets.com/books/1447303603m...
# 1       https://images.gr-assets.com/books/1447303603m...
# 2       https://images.gr-assets.com/books/1447303603m...
# 3       https://images.gr-assets.com/books/1447303603m...
# 4       https://images.gr-assets.com/books/1447303603m...
# ...                                                   ...
# 999907  https://images.gr-assets.com/books/1403194704m...
# 999908  https://images.gr-assets.com/books/1403194704m...
# 999909  https://images.gr-assets.com/books/1403194704m...
# 999910  https://images.gr-assets.com/books/1403194704m...
# 999911  https://images.gr-assets.com/books/1403194704m...
#
#                                           small_image_url  goodreads_book_id  \
# 0       https://images.gr-assets.com/books/1447303603s...            2767052
# 1       https://images.gr-assets.com/books/1447303603s...            2767052
# 2       https://images.gr-assets.com/books/1447303603s...            2767052
# 3       https://images.gr-assets.com/books/1447303603s...            2767052
# 4       https://images.gr-assets.com/books/1447303603s...            2767052
# ...                                                   ...                ...
# 999907  https://images.gr-assets.com/books/1403194704s...               8914
# 999908  https://images.gr-assets.com/books/1403194704s...               8914
# 999909  https://images.gr-assets.com/books/1403194704s...               8914
# 999910  https://images.gr-assets.com/books/1403194704s...               8914
# 999911  https://images.gr-assets.com/books/1403194704s...               8914
#
#         tag_id  count                 tag_name
# 0        30574  11314                  to-read
# 1        11305  10836                  fantasy
# 2        11557  50755                favorites
# 3         8717  35418        currently-reading
# 4        33114  25968              young-adult
# ...        ...    ...                      ...
# 999907   16529      4              john-keegan
# 999908   32805      3                world-war
# 999909   32156      3                  war-ww1
# 999910   20285      3  modern-european-history
# 999911   32915      3              wwi-general
#
# [999912 rows x 27 columns]

# %%
# Display non-truncated columns
pd.reset_option('display.max_colwidth', -1)

# %%
# Store tags into the same book id row
temp_df = books_with_tags.groupby('book_id')['tag_name'].apply(' '.join).reset_index()
temp_df.head(5)
# Out:
#    book_id                                           tag_name
# 0        1  to-read fantasy favorites currently-reading yo...
# 1        2  to-read fantasy favorites currently-reading yo...
# 2        3  to-read fantasy favorites currently-reading yo...
# 3        5  to-read fantasy favorites currently-reading yo...
# 4        6  to-read fantasy young-adult fiction harry-pott...

# %%
# Merge tag_names back into books
books = pd.merge(books, temp_df, left_on='book_id', right_on='book_id', how='inner')

# %%
books
# Out:
#          id  book_id  best_book_id   work_id  books_count        isbn  \
# 0         1  2767052       2767052   2792775          272   439023483
# 1         2        3             3   4640799          491   439554934
# 2         3    41865         41865   3212258          226   316015849
# 3         4     2657          2657   3275794          487    61120081
# 4         5     4671          4671    245494         1356   743273567
# ...     ...      ...           ...       ...          ...         ...
# 9995   9996  7130616       7130616   7392860           19   441019455
# 9996   9997   208324        208324   1084709           19  067973371X
# 9997   9998    77431         77431   2393986           60  039330762X
# 9998   9999  8565083       8565083  13433613            7    61711527
# 9999  10000     8914          8914     11817           31   375700455
#
#             isbn13                      authors  original_publication_year  \
# 0     9.780439e+12              Suzanne Collins                     2008.0
# 1     9.780440e+12  J.K. Rowling, Mary GrandPré                     1997.0
# 2     9.780316e+12              Stephenie Meyer                     2005.0
# 3     9.780061e+12                   Harper Lee                     1960.0
# 4     9.780743e+12          F. Scott Fitzgerald                     1925.0
# ...            ...                          ...                        ...
# 9995  9.780441e+12                Ilona Andrews                     2010.0
# 9996  9.780680e+12               Robert A. Caro                     1990.0
# 9997  9.780393e+12              Patrick O'Brian                     1977.0
# 9998  9.780062e+12              Peggy Orenstein                     2011.0
# 9999  9.780376e+12                  John Keegan                     1998.0
#
#                                          original_title  ...  \
# 0                                      The Hunger Games  ...
# 1              Harry Potter and the Philosopher's Stone  ...
# 2                                              Twilight  ...
# 3                                 To Kill a Mockingbird  ...
# 4                                      The Great Gatsby  ...
# ...                                                 ...  ...
# 9995                                         Bayou Moon  ...
# 9996                                   Means of Ascent   ...
# 9997                              The Mauritius Command  ...
# 9998  Cinderella Ate My Daughter: Dispatches from th...  ...
# 9999                                The First World War  ...
#
#      work_ratings_count work_text_reviews_count  ratings_1  ratings_2  \
# 0               4942365                  155254      66715     127936
# 1               4800065                   75867      75504     101676
# 2               3916824                   95009     456191     436802
# 3               3340896                   72586      60427     117415
# 4               2773745                   51992      86236     197621
# ...                 ...                     ...        ...        ...
# 9995              18856                    1180        105        575
# 9996              12952                     395        303        551
# 9997              10733                     374         11        111
# 9998              11994                    1988        275       1002
# 9999               9700                     364        117        345
#
#       ratings_3  ratings_4  ratings_5  \
# 0        560092    1481305    2706317
# 1        455024    1156318    3011543
# 2        793319     875073    1355439
# 3        446835    1001952    1714267
# 4        606158     936012     947718
# ...         ...        ...        ...
# 9995       3538       7860       6778
# 9996       1737       3389       6972
# 9997       1191       4240       5180
# 9998       3765       4577       2375
# 9999       2031       4138       3069
#
#                                               image_url  \
# 0     https://images.gr-assets.com/books/1447303603m...
# 1     https://images.gr-assets.com/books/1474154022m...
# 2     https://images.gr-assets.com/books/1361039443m...
# 3     https://images.gr-assets.com/books/1361975680m...
# 4     https://images.gr-assets.com/books/1490528560m...
# ...                                                 ...
# 9995  https://images.gr-assets.com/books/1307445460m...
# 9996  https://s.gr-assets.com/assets/nophoto/book/11...
# 9997  https://images.gr-assets.com/books/1455373531m...
# 9998  https://images.gr-assets.com/books/1279214118m...
# 9999  https://images.gr-assets.com/books/1403194704m...
#
#                                         small_image_url  \
# 0     https://images.gr-assets.com/books/1447303603s...
# 1     https://images.gr-assets.com/books/1474154022s...
# 2     https://images.gr-assets.com/books/1361039443s...
# 3     https://images.gr-assets.com/books/1361975680s...
# 4     https://images.gr-assets.com/books/1490528560s...
# ...                                                 ...
# 9995  https://images.gr-assets.com/books/1307445460s...
# 9996  https://s.gr-assets.com/assets/nophoto/book/50...
# 9997  https://images.gr-assets.com/books/1455373531s...
# 9998  https://images.gr-assets.com/books/1279214118s...
# 9999  https://images.gr-assets.com/books/1403194704s...
#
#                                                tag_name
# 0     to-read fantasy favorites currently-reading yo...
# 1     to-read fantasy favorites currently-reading yo...
# 2     to-read fantasy favorites currently-reading yo...
# 3     to-read favorites currently-reading young-adul...
# 4     to-read favorites currently-reading young-adul...
# ...                                                 ...
# 9995  to-read fantasy favorites currently-reading fi...
# 9996  to-read favorites currently-reading books-i-ow...
# 9997  to-read favorites currently-reading fiction bo...
# 9998  to-read favorites currently-reading books-i-ow...
# 9999  to-read favorites currently-reading books-i-ow...
#
# [10000 rows x 24 columns]

# %%
books.columns
# Out:
# Index(['id', 'book_id', 'best_book_id', 'work_id', 'books_count', 'isbn',
#        'isbn13', 'authors', 'original_publication_year', 'original_title',
#        'title', 'language_code', 'average_rating', 'ratings_count',
#        'work_ratings_count', 'work_text_reviews_count', 'ratings_1',
#        'ratings_2', 'ratings_3', 'ratings_4', 'ratings_5', 'image_url',
#        'small_image_url', 'tag_name'],
#       dtype='object')

# %% [markdown]
# ### Feature engineering and machine learning algorithm
#
# * Use TfidVectorizer to transform text to feature vectors
# * Use Cosine Similarity to calculate numeric values that denote the similarity between books

# %%
# Use TfidVectorizer to transform text to feature vectors
tf = TfidfVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(books['tag_name'])

# %%
tfidf_matrix
# Out:
# <10000x144268 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2100874 stored elements in Compressed Sparse Row format>

# %%
# Use Cosine Similarity to calculate numeric values that denote the similarity between books
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)
cosine_sim
# Out:
# array([[1.        , 0.23560979, 0.28324674, ..., 0.05084198, 0.07947133,
#         0.01691533],
#        [0.23560979, 1.        , 0.22459026, ..., 0.0530554 , 0.07126569,
#         0.02330787],
#        [0.28324674, 0.22459026, 1.        , ..., 0.03356699, 0.04251551,
#         0.01473002],
#        ...,
#        [0.05084198, 0.0530554 , 0.03356699, ..., 1.        , 0.0262993 ,
#         0.07240815],
#        [0.07947133, 0.07126569, 0.04251551, ..., 0.0262993 , 1.        ,
#         0.07219924],
#        [0.01691533, 0.02330787, 0.01473002, ..., 0.07240815, 0.07219924,
#         1.        ]])

# %%
# Build a 1-dimensional array with book titles
titles = books['title']
tag_name = books['tag_name']
indices = pd.Series(books.index, index=books['title'])

# Function that gets book recommendations based on the cosine similarity score of book tags
def tags_recommendations(title):
    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:] # How many results to display
    book_indices = [i[0] for i in sim_scores]
    title_df = pd.DataFrame({'title': titles.iloc[book_indices].tolist(),
                           'similarity': [i[1] for i in sim_scores],
                            'tag_name': tag_name.iloc[book_indices].tolist()}, # Maybe remove
                           index=book_indices)
    return title_df

# Function that gets book book tags and stats
def recommend_stats(target_book_title):
    
    # Get recommended books
    rec_df = tags_recommendations(target_book_title)
    
    # Get tags of the target book
    rec_book_tags = books_with_tags[books_with_tags['title'] == target_book_title]['tag_name'].to_list()
    
    # Create dictionary of tag lists by book title
    book_tag_dict = {}
    for title in rec_df['title'].tolist():
        book_tag_dict[title] = books_with_tags[books_with_tags['title'] == title]['tag_name'].to_list()
    
    # Create dictionary of tag statistics by book title
    tags_stats = {}
    for book, tags in book_tag_dict.items():
        tags_stats[book] = {}
        tags_stats[book]['total_tags'] = len(tags)
        same_tags = set(rec_book_tags).intersection(set(tags)) # Get tags in recommended book that are also in target book
        tags_stats[book]['%_common_tags'] = (len(same_tags) / len(tags)) * 100
    
    # Convert dictionary to dataframe
    tags_stats_df = pd.DataFrame.from_dict(tags_stats, orient='index').reset_index().rename(columns={'index': 'title'})
    
    # Merge tag statistics dataframe to recommended books dataframe
    all_stats_df = pd.merge(rec_df, tags_stats_df, on='title')
    return all_stats_df

# %%
# Displays all rows without truncating
# pd.set_option('display.max_rows', None)

# Display all columns with/without truncating (use "set" or "reset")
pd.reset_option('display.max_colwidth')

# %%
lor_recs = recommend_stats('The Fellowship of the Ring (The Lord of the Rings, #1)')

# %%
lor_recs
# Out:
#                                                   title  similarity  \
# 0     The Return of the King (The Lord of the Rings,...    0.865246
# 1            The Two Towers (The Lord of the Rings, #2)    0.846638
# 2     The Lord of the Rings (The Lord of the Rings, ...    0.676849
# 3              The Silmarillion (Middle-Earth Universe)    0.638828
# 4                                            The Hobbit    0.598920
# ...                                                 ...         ...
# 9994  Maryamah Karpov: Mimpi-mimpi Lintang (Tetralog...    0.012938
# 9995                                   The Power of Art    0.012782
# 9996           Veganomicon: The Ultimate Vegan Cookbook    0.011444
# 9997                Edvard Munch: 1863-1944 (Basic Art)    0.011206
# 9998                          رحلتي من الشك إلى الإيمان    0.010575
#
#                                                tag_name  total_tags  \
# 0     to-read fantasy favorites currently-reading yo...         100
# 1     to-read fantasy favorites currently-reading yo...         100
# 2     to-read fantasy favorites currently-reading yo...         100
# 3     to-read fantasy favorites currently-reading yo...         100
# 4     to-read fantasy favorites currently-reading yo...         100
# ...                                                 ...         ...
# 9994  to-read favorites currently-reading young-adul...         100
# 9995  to-read favorites currently-reading default en...         100
# 9996  to-read favorites currently-reading books-i-ow...         100
# 9997  to-read favorites currently-reading books-i-ow...         100
# 9998  to-read favorites currently-reading owned favo...         100
#
#       %_common_tags
# 0              92.0
# 1              90.0
# 2              84.0
# 3              77.0
# 4              76.0
# ...             ...
# 9994           16.0
# 9995            8.0
# 9996           16.0
# 9997            8.0
# 9998           14.0
#
# [9999 rows x 5 columns]

# %%
lor_recs.describe()
# Out:
#         similarity   total_tags  %_common_tags
# count  9999.000000  9999.000000    9999.000000
# mean      0.102142   100.791279      32.267994
# std       0.074227    10.475566       8.851407
# min       0.010575    56.000000       4.000000
# 25%       0.051354   100.000000      26.000000
# 50%       0.077321   100.000000      32.000000
# 75%       0.128045   100.000000      38.000000
# max       0.865246   400.000000      92.000000

# %%
lor_recs.boxplot(column=['similarity'])
plt.show()

# %%
lor_recs.boxplot(column=['%_common_tags'])
plt.show()

# %%
sns.distplot(column=['similarity'], hist=True, kde=True, 
             bins=int(180/5), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-105-724fa5b42c42> in <module>
#       2              bins=int(180/5), color = 'darkblue',
#       3              hist_kws={'edgecolor':'black'},
# ----> 4              kde_kws={'linewidth': 4})
#
# TypeError: distplot() got an unexpected keyword argument 'column'

# %% [markdown]
# ### Reverse engineer

# %%
# Select rows with similarity values between 0.035 to 0.045 and % common tags between 20 to 25
# Zero to One: similarity 0.040449, % common tags 23

lor_recs_filter = lor_recs.loc[(lor_recs['similarity'] >= 0.010575) & (lor_recs['similarity'] <= 0.051354) & (lor_recs['%_common_tags'] >= 22) & (lor_recs['%_common_tags'] <= 23)]
lor_recs_filter
# Out:
#                                                   title  similarity  \
# 7520  The Righteous Mind: Why Good People are Divide...    0.051236
# 7528                   The Incredible Hulk: Planet Hulk    0.051178
# 7538                                             Escape    0.051066
# 7571                                         Lysistrata    0.050694
# 7575    Still Life (Chief Inspector Armand Gamache, #1)    0.050678
# ...                                                 ...         ...
# 9836  The Artist's Way: A Spiritual Path to Higher C...    0.022341
# 9868                          Dude, Where's My Country?    0.021292
# 9889                                 Love Hina, Vol. 01    0.020464
# 9909  Rich Dad's Cashflow Quadrant: Rich Dad's Guide...    0.019728
# 9943                              أحببتك أكثر مما ينبغي    0.017975
#
#                                                tag_name  total_tags  \
# 7520  to-read favorites currently-reading books-i-ow...         100
# 7528  to-read fantasy favorites currently-reading fi...         100
# 7538  to-read favorites currently-reading fiction bo...         100
# 7571  to-read favorites fiction books-i-own owned fa...         100
# 7575  to-read favorites currently-reading fiction bo...         100
# ...                                                 ...         ...
# 9836  to-read favorites currently-reading books-i-ow...         100
# 9868  to-read favorites currently-reading books-i-ow...         100
# 9889  to-read favorites currently-reading young-adul...         100
# 9909  to-read favorites currently-reading books-i-ow...         100
# 9943  to-read favorites currently-reading fiction bo...         100
#
#       %_common_tags
# 7520           22.0
# 7528           23.0
# 7538           23.0
# 7571           23.0
# 7575           23.0
# ...             ...
# 9836           22.0
# 9868           22.0
# 9889           22.0
# 9909           22.0
# 9943           23.0
#
# [338 rows x 5 columns]

# %%
# Merge recommendations with ratings
recs_merge = pd.merge(books, lor_recs, left_on='title', right_on='title', how='inner')
recs_merge

# %%
recs_merge = recs_merge.drop(columns=['best_book_id', 'work_id', 'isbn', 'isbn13', 'image_url', 'small_image_url', 'tag_name_y'])
recs_merge

# %%
# Filter tags unlike most frequent book tag (in this case: 'non-fiction', 'economics' and 'entrepreneurial')
lor_recs_filter = recs_merge[(recs_merge['tag_name_x'].str.contains('non-fiction')) & (recs_merge['tag_name_x'].str.contains('economics')) & (recs_merge['tag_name_x'].str.contains('entrepreneurial'))]

# %%
# pd.reset_option('display.max_colwidth')
pd.set_option('display.max_rows', 400)
lor_recs_filter = lor_recs_filter.sort_values(by=['average_rating'], ascending=False)
lor_recs_filter

# %% [markdown]
# ### Explore the book data

# %%
# Use TfidVectorizer to transform text to feature vectors
tf = TfidfVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(books['tag_name'])

# Find the index of Lord of the Rings
tfidf_matrix[1]

# Find the index of Zero to One
tfidf_matrix[2]

# tfidf_matrix['index']   # will output row of tfidf values

tf.get_feature_names()

# %%
tfidf_matrix[1].todense()
# Out:
# matrix([[0., 0., 0., ..., 0., 0., 0.]])

# %%
tfidf_matrix[2].todense()
# Out:
# matrix([[0., 0., 0., ..., 0., 0., 0.]])

# %%
tf.get_feature_names()
# Out:
# ['00',
#  '00 04',
#  '00 100',
#  '00 batman',
#  '00 class',
#  '00 cookbooks',
#  '00 exploring',
#  '00 fall',
#  '00 graphic',
#  '00 poem',
#  '00 pre',
#  '00 read',
#  '00 toread_comics',
#  '000',
#  '000 books',
#  '000 horus',
#  '000 uncategorized',
#  '0000',
#  '0000 buy',
#  '0000 christian',
#  '0000 medio',
#  '0000 need',
#  '0000 pre',
#  '00000',
#  '00000 physical',
#  '00000 reality',
#  '0000_notverified',
#  '0000_notverified oeuvre',
#  '000src',
#  '000src 15',
#  '000src su',
#  '001',
#  '001 150',
#  '001 ebook',
#  '002',
#  '002 read',
#  '002 une',
#  '005',
#  '005 classicy',
#  '007',
#  '007 mysteries',
#  '007 spy',
#  '008',
#  '008 strategy',
#  '01',
#  '01 alphabet',
#  '01 books',
#  '01 classics',
#  '01 college',
#  '01 devotions',
#  '01 distopias',
#  '01 ecookbooks',
#  '01 folklore',
#  '01 irl',
#  '01 nonfiction',
#  '01 recs',
#  '01 romantics',
#  '01 sf',
#  '01 suggestions',
#  '01 tbr',
#  '01 words',
#  '016',
#  '016 sam',
#  '01_best',
#  '01_best books',
#  '02',
#  '02 500',
#  '02 ala',
#  '02 black',
#  '02 fantasy',
#  '02 folklore',
#  '02 lovecraft',
#  '02 ncss',
#  '02 read',
#  '02 words',
#  '0201',
#  '0201 0300',
#  '021614',
#  '021614 library',
#  '0227528',
#  '0227528 dewey',
#  '029',
#  '029 نجيب',
#  '03',
#  '03 1600',
#  '03 20thcentury',
#  '03 classic',
#  '03 historical',
#  '03 informational',
#  '03 sami',
#  '03 star',
#  '03 words',
#  '0300',
#  '0300 pages',
#  '0303',
#  '0303 0227528',
#  '04',
#  '04 06',
#  '04 17',
#  '04 alphabet',
#  '04 available',
#  '04 babies',
#  '04 caldecott',
#  '04 counting',
#  '04 easy',
#  '04 preschoolers',
#  '04 realistic',
#  '04 star',
#  '04 stars',
#  '04 transitional',
#  '0471239720',
#  '0471239720 life',
#  '05',
#  '05 09',
#  '05 high',
#  '05ip9hg',
#  '05ip9hg want',
#  '06',
#  '06 dvd',
#  '06 kind',
#  '06 traditional',
#  '07',
#  '07 hist',
#  '07 modern',
#  '07 まんが',
#  '07july',
#  '07july hall',
#  '08',
#  '08 childhood',
#  '08 likee',
#  '08 p_taschen',
#  '08 realistic',
#  '08 words',
#  '09',
#  '09 higher',
#  '09 pop',
#  '0cant',
#  '0cant tw',
#  '0fiction',
#  '0fiction incomplete',
#  '0nonfiction',
#  '0nonfiction read_2016',
#  '0want',
#  '0want cozinha',
#  '0wn',
#  '0wn apologetics',
#  '0wn child',
#  '0wn dave',
#  '0wn easy',
#  '0wn growing',
#  '0wn kid',
#  '0wn kiddos',
#  '0wn read',
#  '0wn summer',
#  '0wn wwdb',
#  '0wned',
#  '0wned books',
#  '10',
#  '10 2004',
#  '10 art',
#  '10 asimov',
#  '10 aussie',
#  '10 books',
#  '10 boy',
#  '10 dollars',
#  '10 duncan',
#  '10 french',
#  '10 halo',
#  '10 hb',
#  '10 iris',
#  '10 read',
#  '10 religija',
#  '10 series',
#  '10 shit',
#  '10 times',
#  '10 words',
#  '10 year',
#  '10 years',
#  '10 مكتبتي',
#  '100',
#  '100 100',
#  '100 1001',
#  '100 1910s',
#  '100 1920s',
#  '100 1930s',
#  '100 1940s',
#  '100 2001',
#  '100 2007',
#  '100 20th',
#  '100 50',
#  '100 absolute',
#  '100 adultery',
#  '100 african',
#  '100 amazon',
#  '100 american',
#  '100 anton',
#  '100 ap',
#  '100 arranged',
#  '100 asia',
#  '100 asian',
#  '100 author',
#  '100 autobiography',
#  '100 available',
#  '100 aviation',
#  '100 banned',
#  '100 barthelme',
#  '100 bbc',
#  '100 best',
#  '100 big',
#  '100 black',
#  '100 board',
#  '100 bokklubben',
#  '100 book',
#  '100 books',
#  '100 bullets',
#  '100 california',
#  '100 canadian',
#  '100 caribbean',
#  '100 catholic',
#  '100 chef',
#  '100 chick',
#  '100 childhood',
#  '100 children',
#  '100 childrens',
#  '100 christianity',
#  '100 civil',
#  '100 class',
#  '100 classic',
#  '100 classics',
#  '100 coaching',
#  '100 comic',
#  '100 controversial',
#  '100 counterculture',
#  '100 crime',
#  '100 cute',
#  '100 daria',
#  '100 dark',
#  '100 death',
#  '100 denmark',
#  '100 deutsche',
#  '100 disturbing',
#  '100 diversity',
#  '100 dropped',
#  '100 edith',
#  '100 edwardian',
#  '100 end',
#  '100 epic',
#  '100 erskine',
#  '100 esquire',
#  '100 essential',
#  '100 european',
#  '100 existentialism',
#  '100 family',
#  '100 fantasy',
#  '100 fantasía',
#  '100 favorite',
#  '100 feminism',
#  '100 feminist',
#  '100 fic',
#  '100 fiction',
#  '100 fitness',
#  '100 free',
#  '100 french',
#  '100 genocide',
#  '100 genre',
#  '100 georgia',
#  '100 georgian',
#  '100 gibson',
#  '100 gilmore',
#  '100 gonzo',
#  '100 graphic',
#  '100 greatest',
#  '100 hard',
#  '100 hate',
#  '100 hemingway',
#  '100 hist',
#  '100 historical',
#  '100 history',
#  '100 india',
#  '100 irish',
#  '100 jamaica',
#  '100 japanese',
#  '100 japoneses',
#  '100 jennifer',
#  '100 kass',
#  '100 keyes',
#  '100 kid',
#  '100 killer',
#  '100 kindlecollection',
#  '100 la',
#  '100 larry',
#  '100 lgbt',
#  '100 list',
#  '100 lit',
#  '100 martin',
#  '100 medieval',
#  '100 men',
#  '100 metafiction',
#  '100 mind',
#  '100 ministry',
#  '100 minnesota',
#  '100 mishima',
#  '100 modern',
#  '100 modernism',
#  '100 movies',
#  '100 multicultural',
#  '100 mystery',
#  '100 mythology',
#  '100 national',
#  '100 need',
#  '100 nihilism',
#  '100 nobel',
#  '100 noir',
#  '100 non',
#  '100 nonfiction',
#  '100 novel',
#  '100 novels',
#  '100 operations',
#  '100 oprah',
#  '100 outdoors',
#  '100 overdrive',
#  '100 owned',
#  '100 papua',
#  '100 pennsylvania',
#  '100 philip',
#  '100 picaresque',
#  '100 picture',
#  '100 poland',
#  '100 political',
#  '100 pomo',
#  '100 postmodern',
#  '100 poverty',
#  '100 priority',
#  '100 psychology',
#  '100 public',
#  '100 queue',
#  '100 read',
#  '100 realism',
#  '100 realistic',
#  '100 recommended',
#  '100 romance',
#  '100 rory',
#  '100 russi',
#  '100 ryan',
#  '100 saga',
#  '100 school',
#  '100 sci',
#  '100 scifi',
#  '100 scotland',
#  '100 sea',
#  '100 series',
#  '100 sff',
#  '100 sinclair',
#  '100 social',
#  '100 soon',
#  '100 southern',
#  '100 soviet',
#  '100 sports',
#  '100 started',
#  '100 stephen',
#  '100 stopped',
#  '100 stream',
#  '100 summer',
#  '100 suspense',
#  '100 sword',
#  '100 tales',
#  '100 tbr',
#  '100 teen',
#  '100 terrorism',
#  '100 theodore',
#  '100 thomas',
#  '100 thrillers',
#  '100 time',
#  '100 time100',
#  '100 times',
#  '100 tragedy',
#  '100 true',
#  '100 want',
#  '100 war',
#  '100 weird',
#  '100 western',
#  '100 women',
#  '100 ww2',
#  '100 ya',
#  '100 year',
#  '100 years',
#  '100 رواية',
#  '1000',
#  '1000 1001',
#  '1000 1001books',
#  '1000 1870s',
#  '1000 1930s',
#  '1000 1950s',
#  '1000 19th',
#  '1000 2015',
#  '1000 20th',
#  '1000 book',
#  '1000 books',
#  '1000 business',
#  '1000 childhood',
#  '1000 classic',
#  '1000 crime',
#  '1000 eliot',
#  '1000 english',
#  '1000 español',
#  '1000 favoritos',
#  '1000 fiction',
#  '1000 finished',
#  '1000 german',
#  '1000 good',
#  '1000 gothic',
#  '1000 grad',
#  '1000 harry',
#  '1000 horror',
#  '1000 latin',
#  '1000 library',
#  '1000 magic',
#  '1000 magical',
#  '1000 mental',
#  '1000 national',
#  '1000 new',
#  '1000 nobel',
#  '1000 novels',
#  '1000 plus',
#  '1000 quarter',
#  '1000 read',
#  '1000 romans',
#  '1000 rory',
#  '1000 short',
#  '1000 suspense',
#  '1000 thrillers',
#  '1000 time',
#  '1000 victoriana',
#  '1000 victorians',
#  '1000 women',
#  '1000 world',
#  '1000 ww2',
#  '10000',
#  '10000 au',
#  '1000s',
#  '1000s 1300s',
#  '1001',
#  '1001 1001',
#  '1001 1930s',
#  '1001 20th',
#  '1001 abandoned',
#  '1001 abuse',
#  '1001 book',
#  '1001 books',
#  '1001 bymrbyd',
#  '1001 challenge',
#  '1001 children',
#  '1001 childrens',
#  '1001 comics',
#  '1001 die',
#  '1001 ebooks',
#  '1001 import',
#  '1001 irish',
#  '1001 kids',
#  '1001 libri',
#  '1001 list',
#  '1001 literatura',
#  '1001 literature',
#  '1001 music',
#  '1001 non',
#  '1001 read',
#  '1001 reads',
#  '1001 science',
#  '1001 speculative',
#  '1001 stars',
#  '1001 unread',
#  '1001books',
#  '1001books 1001',
#  '1001books boxall',
#  '1001books california',
#  '1001books counterculture',
#  '1001books english',
#  '1001books espionage',
#  '1001books female',
#  '1001books feminism',
#  '1001books letteratura',
#  '1001books literatura',
#  '1001books literature',
#  '1001books metafiction',
#  '1001books mystery',
#  '1001books national',
#  '1001books need',
#  '1001books nobel',
#  '1001books noir',
#  '1001books paul',
#  '1001books political',
#  '1001books romans',
#  '1001books uni',
#  '1001books weird',
#  '1001books women',
#  '1001books ww2',
#  '1001books york',
#  '1009',
#  '1009 global',
#  '100s',
#  '100s books',
#  '101',
#  '101 bibles',
#  '101 books',
#  '101 lire',
#  '101st',
#  '101st airborne',
#  '102',
#  '102 miscellaneous',
#  '103',
#  '103 simply',
#  '10k',
#  '10k 1910s',
#  '10k adored',
#  '10k cult',
#  '10k delete',
#  '10k kitchen',
#  '10k rest',
#  '10k unlikely',
#  '10th',
#  '10th century',
#  '10th grade',
#  '11',
#  '11 1001',
#  '11 11',
#  '11 20',
#  '11 2009',
#  '11 2012',
#  '11 2014',
#  '11 30',
#  '11 adult',
#  '11 american',
#  '11 asian',
#  '11 awesome',
#  '11 birthdays',
#  '11 book',
#  '11 children',
#  '11 class',
#  '11 daily',
#  '11 disabilities',
#  '11 grief',
#  '11 ian',
#  '11 jack',
#  '11 lucky',
#  '11 man',
#  '11 non',
#  '11 november',
#  '11 pakistan',
#  '11 pen',
#  '11 por',
#  '11 read',
#  '11 reads',
#  '11 september',
#  '11 series',
#  '11 south',
#  '11 war',
#  '110',
#  '110 angstrom',
#  '110 midlife',
#  '110 passing',
#  '1100s',
#  '111',
#  '111 hi',
#  '111 interior',
#  '1111',
#  '1111 books',
#  '11th',
#  '11th century',
#  '11th grade',
#  '12',
#  '12 01',
#  '12 1001',
#  '12 13',
#  '12 14',
#  '12 birds',
#  '12 books',
#  '12 caudill',
#  '12 contemporary',
#  '12 dancing',
#  '12 fear',
#  '12 folktale',
#  '12 global',
#  '12 haunted',
#  '12 january',
#  '12 juv',
#  '12 lived',
#  '12 manga',
#  '12 novels',
#  '12 powers',
#  '12 read',
#  '12 religious',
#  '12 school',
#  '12 series',
#  '12 southern',
#  '12 stargirl',
#  '12 summer',
#  '12 teen',
#  '12 thomas',
#  '12 united',
#  '12 written',
#  '12 ya',
#  '12 كتبي',
#  '12017',
#  '12017 bp',
#  '122',
#  '122 keys',
#  '123',
#  '123 21st',
#  '123 wattpad',
#  '123 zzz',
#  '12s',
#  '12s whish',
#  '12th',
#  '12th century',
#  '12th grade',
#  '13',
#  '13 16',
#  '13 25',
#  '13 9781481280761',
#  '13 agent',
#  '13 gifts',
#  '13 man',
#  '13 nf',
#  '13 series',
#  '1300',
#  '1300 1350',
#  '1300s',
#  '1300s fiction',
#  '1350',
#  '1350 english',
#  '1395',
#  '1395 ادبیات',
#  '13th',
#  '13th century',
#  '14',
#  '14 black',
#  '14 disguise',
#  '14 figure',
#  '14 fixtures',
#  '14 read',
#  '14 series',
#  '14 tbb',
#  '14 عباس',
#  '1400s',
#  '1400s 1600s',
#  '1400s ricardian',
#  '140924',
#  '140924 150913',
#  '1421',
#  '1421 1737',
#  '1421 pseudo',
#  '1438',
#  '1438 2016',
#  '1452',
#  '1452 1519',
#  '14th',
#  '14th century',
#  '14艺术美学',
#  '14艺术美学 arty',
#  '15',
#  '15 01',
#  '15 16',
#  '15 age',
#  '15 best',
#  '15 classroom',
#  '15 cooking',
#  '15 independent',
#  '15 read',
#  '15 recommended',
#  '15 series',
#  '15 subtitle',
#  '15 words',
#  '150',
#  '150 best',
#  '150 pages',
#  '1500',
#  '1500 medieval',
#  '1500s',
#  '1500s conquistadors',
#  '1500s devil',
#  '1500s dystopia',
#  '1500s gilmore',
#  '1500s greatest',
#  '1500s henry',
#  '1500s literature',
#  '1500s mystery',
#  '1500s partly',
#  '1500s picaresque',
#  '1500s plays',
#  '1500s rape',
#  '1500s read',
#  '1500s reading',
#  '1500s unread',
#  '150321',
#  '150321 160409',
#  '1507',
#  '1507 office',
#  '150913',
#  '150913 r351',
#  '1519',
#  '1537',
#  '1537 1553',
#  '1543',
#  '1553',
#  '1564',
#  '1564 1616',
#  '158',
#  '158 depth',
#  '15th',
#  '15th century',
#  '16',
#  '16 age',
#  '16 botm',
#  '16 busienss',
#  '16 daniella',
#  '16 inspector',
#  '16 jordan',
#  '16 kindle',
#  '16 middle',
#  '16 netgalley',
#  '16 priority',
#  '16 school',
#  '1600',
#  '1600 1850',
#  '1600s',
#  '1600s 50',
#  '1600s class',
#  '1600s english',
#  '1600s history',
#  '1600s india',
#  '1600s married',
#  '1600s medicine',
#  '1600s philosophy',
#  '1600s poesia',
#  '1600s read',
#  '1600s theology',
#  '1600s undergrad',
#  '1600s want',
#  '160409',
#  '160409 140924',
#  '1616',
#  '1616 daughters',
#  '1643',
#  '1643 1715',
#  '166',
#  '166 17',
#  '1660s',
#  '1660s 1665',
#  '1665',
#  '1665 harvard',
#  '16th',
#  '16th 18th',
#  '16th century',
#  '16th five_stars',
#  '17',
#  '17 1st',
#  '17 25',
#  '17 arte',
#  '17 benefit',
#  '17 children',
#  '17 cottonwood',
#  '17 fiction',
#  '17 pendientes',
#  '17 read',
#  '17 series',
#  '1700',
#  '1700 shake',
#  '1700s',
#  '1700s 100',
#  '1700s 2011',
#  '1700s 50',
#  '1700s 501',
#  '1700s british',
#  '1700s brothers',
#  '1700s canlit',
#  '1700s daniel',
#  '1700s epistolary',
#  '1700s hist',
#  '1700s irish',
#  '1700s kindle',
#  '1700s kobo',
#  '1700s outlander',
#  '1700s philosophy',
#  '1700s picaresque',
#  '1700s politics',
#  '1700s teens',
#  '1700s terror',
#  '1700s voltaire',
#  '1702',
#  '1702 1714',
#  '1714',
#  '1715',
#  '1715 baroque',
#  '1737',
#  '1775',
#  '1775 1783',
#  '1775 1800',
#  '1776',
#  '1776 period',
#  '1783',
#  '1783 george',
#  '1790s',
#  '1793',
#  '1793 children',
#  '17th',
#  '17th century',
#  '18',
#  '18 2011',
#  '18 books',
#  '18 child',
#  '18 creativity',
#  '18 original',
#  '18 powells',
#  '1800',
#  '1800 1775',
#  '1800 1900',
#  '1800 art',
#  '1800 international',
#  '1800 johnstown',
#  '1800 kindle',
#  '1800 massachusetts',
#  '1800s',
#  '1800s 1001',
#  '1800s 19th',
#  '1800s bio',
#  '1800s books',
#  '1800s brit',
#  '1800s chick',
#  '1800s classici',
#  '1800s crime',
#  '1800s digital',
#  '1800s educated',
#  '1800s fiction',
#  '1800s french',
#  '1800s historic',
#  '1800s horror',
#  '1800s italy',
#  '1800s library',
#  '1800s nautical',
#  '1800s new',
#  '1800s nineteenth',
#  '1800s novella',
#  '1800s novellas',
#  '1800s paper',
#  '1800s penguin',
#  '1800s pirates',
#  '1800s poetry',
#  '1800s read',
#  '1800s realism',
#  '1800s roman',
#  '1800s romantic',
#  '1800s rory',
#  '1800s spiritual',
#  '1800s spirituality',
#  '1800s tbr',
#  '1800s translated',
#  '1800s victoriana',
#  '1800s women',
#  '1800s روايات',
#  '1812',
#  '1812 1870',
#  '1820s',
#  '1820s read',
#  '1830s',
#  '1830s balzac',
#  '1830s british',
#  '1830s dickens',
#  '1830s folio',
#  '1830s francese',
#  '1830s world',
#  '1840s',
#  '1840s english',
#  '1840s guardian',
#  '1840s read',
#  '1840s أدب',
#  '1844',
#  '1844 1900',
#  '1850',
#  '1850 800',
#  '1850 runaway',
#  '1850s',
#  '1850s fiction',
#  '1850s symbolism',
#  '1850s русская',
#  '1851',
#  '1851 1900',
#  '1854',
#  '1854 republican',
#  '1860s',
#  '1860s historical',
#  '1860s read',
#  '1863',
#  '1863 contemporary',
#  '187',
#  '187 art',
#  '1870',
#  '1870 ghost',
#  '1870s',
#  '1870s 19th',
#  '1870s eliot',
#  '1871',
#  '1871 1945',
#  '1880s',
#  '1880s 1001',
#  '1880s cc',
#  '1880s ensayos',
#  '1880s litterature',
#  '1880s reading',
#  '1880s rider',
#  '1880s thomas',
#  '1883',
#  '1883 1924',
#  '1888',
#  '1888 1955',
#  '1890s',
#  '1890s european',
#  '1890s klassikot',
#  '1890s thomas',
#  '1890s twain',
#  '1890s weird',
#  '1890s نمایشنامه',
#  '18th',
#  '18th 100',
#  '18th century',
#  '18th epistolary',
#  '18th repentance',
#  '19',
#  '19 alex',
#  '19 rice',
#  '1900',
#  '1900 1600',
#  '1900 1960s',
#  '1900 1969',
#  '1900 2000',
#  '1900 french',
#  '1900 narrative',
#  '1900 nouvelles',
#  '1900 obtain',
#  '1900 storm',
#  '1900 theatre',
#  '1900 unknown',
#  '1900 w_europa_norvegia',
#  '1900s',
#  '1900s 1001',
#  '1900s 1001books',
#  '1900s 1950s',
#  '1900s 20th',
#  '1900s asia',
#  '1900s banned',
#  '1900s bio',
#  '1900s brit',
#  '1900s classic',
#  '1900s classici',
#  '1900s colonialism',
#  '1900s controversial',
#  '1900s crime',
#  '1900s ebooks',
#  '1900s educated',
#  '1900s environment',
#  '1900s erotica',
#  '1900s farm',
#  '1900s fiction',
#  '1900s french',
#  '1900s italy',
#  '1900s jewish',
#  '1900s library',
#  '1900s new',
#  '1900s nostalgia',
#  '1900s novela',
#  '1900s novellas',
#  '1900s penguin',
#  '1900s read',
#  '1900s roman',
#  '1900s rory',
#  '1900s scottish',
#  '1900s sexuality',
#  '1900s translated',
#  '1900s victorian',
#  '1900s vietnam',
#  '1900s women',
#  '1902',
#  '1904',
#  '1904 archetypes',
#  '1907',
#  '1907 sahin',
#  '1908',
#  '1910s',
#  '1910s 100',
#  '1910s 2012',
#  '1910s 2015',
#  '1910s 2016',
#  '1910s bloomsbury',
#  '1910s british',
#  '1910s burroughs',
#  '1910s childhood',
#  '1910s existentialism',
#  '1910s families',
#  '1910s farming',
#  '1910s gilmore',
#  '1910s guardian',
#  ...]

# %%
matrix_df = pd.DataFrame(tfidf_matrix.todense(), columns=tf.get_feature_names(), index=books['title'])

# %%
matrix_df
# Out:
#                                                      00  00 04  00 100  \
# title
# The Hunger Games (The Hunger Games, #1)             0.0    0.0     0.0
# Harry Potter and the Sorcerer's Stone (Harry Po...  0.0    0.0     0.0
# Twilight (Twilight, #1)                             0.0    0.0     0.0
# To Kill a Mockingbird                               0.0    0.0     0.0
# The Great Gatsby                                    0.0    0.0     0.0
# ...                                                 ...    ...     ...
# Bayou Moon (The Edge, #2)                           0.0    0.0     0.0
# Means of Ascent (The Years of Lyndon Johnson, #2)   0.0    0.0     0.0
# The Mauritius Command                               0.0    0.0     0.0
# Cinderella Ate My Daughter: Dispatches from the...  0.0    0.0     0.0
# The First World War                                 0.0    0.0     0.0
#
#                                                     00 batman  00 class  \
# title
# The Hunger Games (The Hunger Games, #1)                   0.0       0.0
# Harry Potter and the Sorcerer's Stone (Harry Po...        0.0       0.0
# Twilight (Twilight, #1)                                   0.0       0.0
# To Kill a Mockingbird                                     0.0       0.0
# The Great Gatsby                                          0.0       0.0
# ...                                                       ...       ...
# Bayou Moon (The Edge, #2)                                 0.0       0.0
# Means of Ascent (The Years of Lyndon Johnson, #2)         0.0       0.0
# The Mauritius Command                                     0.0       0.0
# Cinderella Ate My Daughter: Dispatches from the...        0.0       0.0
# The First World War                                       0.0       0.0
#
#                                                     00 cookbooks  \
# title
# The Hunger Games (The Hunger Games, #1)                      0.0
# Harry Potter and the Sorcerer's Stone (Harry Po...           0.0
# Twilight (Twilight, #1)                                      0.0
# To Kill a Mockingbird                                        0.0
# The Great Gatsby                                             0.0
# ...                                                          ...
# Bayou Moon (The Edge, #2)                                    0.0
# Means of Ascent (The Years of Lyndon Johnson, #2)            0.0
# The Mauritius Command                                        0.0
# Cinderella Ate My Daughter: Dispatches from the...           0.0
# The First World War                                          0.0
#
#                                                     00 exploring  00 fall  \
# title
# The Hunger Games (The Hunger Games, #1)                      0.0      0.0
# Harry Potter and the Sorcerer's Stone (Harry Po...           0.0      0.0
# Twilight (Twilight, #1)                                      0.0      0.0
# To Kill a Mockingbird                                        0.0      0.0
# The Great Gatsby                                             0.0      0.0
# ...                                                          ...      ...
# Bayou Moon (The Edge, #2)                                    0.0      0.0
# Means of Ascent (The Years of Lyndon Johnson, #2)            0.0      0.0
# The Mauritius Command                                        0.0      0.0
# Cinderella Ate My Daughter: Dispatches from the...           0.0      0.0
# The First World War                                          0.0      0.0
#
#                                                     00 graphic  00 poem  ...  \
# title                                                                    ...
# The Hunger Games (The Hunger Games, #1)                    0.0      0.0  ...
# Harry Potter and the Sorcerer's Stone (Harry Po...         0.0      0.0  ...
# Twilight (Twilight, #1)                                    0.0      0.0  ...
# To Kill a Mockingbird                                      0.0      0.0  ...
# The Great Gatsby                                           0.0      0.0  ...
# ...                                                        ...      ...  ...
# Bayou Moon (The Edge, #2)                                  0.0      0.0  ...
# Means of Ascent (The Years of Lyndon Johnson, #2)          0.0      0.0  ...
# The Mauritius Command                                      0.0      0.0  ...
# Cinderella Ate My Daughter: Dispatches from the...         0.0      0.0  ...
# The First World War                                        0.0      0.0  ...
#
#                                                     ｆａｖｏｒｉｔｅｓ games  \
# title
# The Hunger Games (The Hunger Games, #1)                         0.0
# Harry Potter and the Sorcerer's Stone (Harry Po...              0.0
# Twilight (Twilight, #1)                                         0.0
# To Kill a Mockingbird                                           0.0
# The Great Gatsby                                                0.0
# ...                                                             ...
# Bayou Moon (The Edge, #2)                                       0.0
# Means of Ascent (The Years of Lyndon Johnson, #2)               0.0
# The Mauritius Command                                           0.0
# Cinderella Ate My Daughter: Dispatches from the...              0.0
# The First World War                                             0.0
#
#                                                     ｆａｖｏｒｉｔｅｓ george  \
# title
# The Hunger Games (The Hunger Games, #1)                          0.0
# Harry Potter and the Sorcerer's Stone (Harry Po...               0.0
# Twilight (Twilight, #1)                                          0.0
# To Kill a Mockingbird                                            0.0
# The Great Gatsby                                                 0.0
# ...                                                              ...
# Bayou Moon (The Edge, #2)                                        0.0
# Means of Ascent (The Years of Lyndon Johnson, #2)                0.0
# The Mauritius Command                                            0.0
# Cinderella Ate My Daughter: Dispatches from the...               0.0
# The First World War                                              0.0
#
#                                                     ｆａｖｏｒｉｔｅｓ gothic  \
# title
# The Hunger Games (The Hunger Games, #1)                          0.0
# Harry Potter and the Sorcerer's Stone (Harry Po...               0.0
# Twilight (Twilight, #1)                                          0.0
# To Kill a Mockingbird                                            0.0
# The Great Gatsby                                                 0.0
# ...                                                              ...
# Bayou Moon (The Edge, #2)                                        0.0
# Means of Ascent (The Years of Lyndon Johnson, #2)                0.0
# The Mauritius Command                                            0.0
# Cinderella Ate My Daughter: Dispatches from the...               0.0
# The First World War                                              0.0
#
#                                                     ｆａｖｏｒｉｔｅｓ neuroscience  \
# title
# The Hunger Games (The Hunger Games, #1)                                0.0
# Harry Potter and the Sorcerer's Stone (Harry Po...                     0.0
# Twilight (Twilight, #1)                                                0.0
# To Kill a Mockingbird                                                  0.0
# The Great Gatsby                                                       0.0
# ...                                                                    ...
# Bayou Moon (The Edge, #2)                                              0.0
# Means of Ascent (The Years of Lyndon Johnson, #2)                      0.0
# The Mauritius Command                                                  0.0
# Cinderella Ate My Daughter: Dispatches from the...                     0.0
# The First World War                                                    0.0
#
#                                                     ｆａｖｏｒｉｔｅｓ siege  \
# title
# The Hunger Games (The Hunger Games, #1)                         0.0
# Harry Potter and the Sorcerer's Stone (Harry Po...              0.0
# Twilight (Twilight, #1)                                         0.0
# To Kill a Mockingbird                                           0.0
# The Great Gatsby                                                0.0
# ...                                                             ...
# Bayou Moon (The Edge, #2)                                       0.0
# Means of Ascent (The Years of Lyndon Johnson, #2)               0.0
# The Mauritius Command                                           0.0
# Cinderella Ate My Daughter: Dispatches from the...              0.0
# The First World War                                             0.0
#
#                                                     ｆａｖｏｕｒｉｔｅｓ  ｍａｎｇａ  \
# title
# The Hunger Games (The Hunger Games, #1)                    0.0    0.0
# Harry Potter and the Sorcerer's Stone (Harry Po...         0.0    0.0
# Twilight (Twilight, #1)                                    0.0    0.0
# To Kill a Mockingbird                                      0.0    0.0
# The Great Gatsby                                           0.0    0.0
# ...                                                        ...    ...
# Bayou Moon (The Edge, #2)                                  0.0    0.0
# Means of Ascent (The Years of Lyndon Johnson, #2)          0.0    0.0
# The Mauritius Command                                      0.0    0.0
# Cinderella Ate My Daughter: Dispatches from the...         0.0    0.0
# The First World War                                        0.0    0.0
#
#                                                     ｍａｎｇａ berserk  ｓｅｒｉｅｓ  \
# title
# The Hunger Games (The Hunger Games, #1)                       0.0     0.0
# Harry Potter and the Sorcerer's Stone (Harry Po...            0.0     0.0
# Twilight (Twilight, #1)                                       0.0     0.0
# To Kill a Mockingbird                                         0.0     0.0
# The Great Gatsby                                              0.0     0.0
# ...                                                           ...     ...
# Bayou Moon (The Edge, #2)                                     0.0     0.0
# Means of Ascent (The Years of Lyndon Johnson, #2)             0.0     0.0
# The Mauritius Command                                         0.0     0.0
# Cinderella Ate My Daughter: Dispatches from the...            0.0     0.0
# The First World War                                           0.0     0.0
#
#                                                     ｓｅｒｉｅｓ carpathian
# title
# The Hunger Games (The Hunger Games, #1)                           0.0
# Harry Potter and the Sorcerer's Stone (Harry Po...                0.0
# Twilight (Twilight, #1)                                           0.0
# To Kill a Mockingbird                                             0.0
# The Great Gatsby                                                  0.0
# ...                                                               ...
# Bayou Moon (The Edge, #2)                                         0.0
# Means of Ascent (The Years of Lyndon Johnson, #2)                 0.0
# The Mauritius Command                                             0.0
# Cinderella Ate My Daughter: Dispatches from the...                0.0
# The First World War                                               0.0
#
# [10000 rows x 144268 columns]

# %%
matrix_df['title'].dtype
# Out:
# dtype('float64')

# %%
# Convert to string
matrix_df['title'] = matrix_df.title.astype(str)

# %%
matrix_df['title'].dtype
# Out:
# dtype('O')

# %%
matrix_df[matrix_df['title'].str.match('The Great Gatsby')]
# Out:
# Empty DataFrame
# Columns: [00, 00 04, 00 100, 00 batman, 00 class, 00 cookbooks, 00 exploring, 00 fall, 00 graphic, 00 poem, 00 pre, 00 read, 00 toread_comics, 000, 000 books, 000 horus, 000 uncategorized, 0000, 0000 buy, 0000 christian, 0000 medio, 0000 need, 0000 pre, 00000, 00000 physical, 00000 reality, 0000_notverified, 0000_notverified oeuvre, 000src, 000src 15, 000src su, 001, 001 150, 001 ebook, 002, 002 read, 002 une, 005, 005 classicy, 007, 007 mysteries, 007 spy, 008, 008 strategy, 01, 01 alphabet, 01 books, 01 classics, 01 college, 01 devotions, 01 distopias, 01 ecookbooks, 01 folklore, 01 irl, 01 nonfiction, 01 recs, 01 romantics, 01 sf, 01 suggestions, 01 tbr, 01 words, 016, 016 sam, 01_best, 01_best books, 02, 02 500, 02 ala, 02 black, 02 fantasy, 02 folklore, 02 lovecraft, 02 ncss, 02 read, 02 words, 0201, 0201 0300, 021614, 021614 library, 0227528, 0227528 dewey, 029, 029 نجيب, 03, 03 1600, 03 20thcentury, 03 classic, 03 historical, 03 informational, 03 sami, 03 star, 03 words, 0300, 0300 pages, 0303, 0303 0227528, 04, 04 06, 04 17, 04 alphabet, ...]
# Index: []
#
# [0 rows x 144268 columns]

# %%
matrix_df.iloc[18]
# Out:
# 00                   0
# 00 04                0
# 00 100               0
# 00 batman            0
# 00 class             0
#                     ..
# ｆａｖｏｕｒｉｔｅｓ           0
# ｍａｎｇａ                0
# ｍａｎｇａ berserk        0
# ｓｅｒｉｅｓ               0
# ｓｅｒｉｅｓ carpathian    0
# Name: The Fellowship of the Ring (The Lord of the Rings, #1), Length: 144268, dtype: object

# %%
matrix_df.iloc[2165]
# Out:
# 00                   0
# 00 04                0
# 00 100               0
# 00 batman            0
# 00 class             0
#                     ..
# ｆａｖｏｕｒｉｔｅｓ           0
# ｍａｎｇａ                0
# ｍａｎｇａ berserk        0
# ｓｅｒｉｅｓ               0
# ｓｅｒｉｅｓ carpathian    0
# Name: Zero to One: Notes on Startups, or How to Build the Future, Length: 144268, dtype: object

# %%
compare_df = matrix_df.iloc[[18,2165]]
compare_df
# Out:
#                                                      00  00 04  00 100  \
# title
# The Fellowship of the Ring (The Lord of the Rin...  0.0    0.0     0.0
# Zero to One: Notes on Startups, or How to Build...  0.0    0.0     0.0
#
#                                                     00 batman  00 class  \
# title
# The Fellowship of the Ring (The Lord of the Rin...        0.0       0.0
# Zero to One: Notes on Startups, or How to Build...        0.0       0.0
#
#                                                     00 cookbooks  \
# title
# The Fellowship of the Ring (The Lord of the Rin...           0.0
# Zero to One: Notes on Startups, or How to Build...           0.0
#
#                                                     00 exploring  00 fall  \
# title
# The Fellowship of the Ring (The Lord of the Rin...           0.0      0.0
# Zero to One: Notes on Startups, or How to Build...           0.0      0.0
#
#                                                     00 graphic  00 poem  ...  \
# title                                                                    ...
# The Fellowship of the Ring (The Lord of the Rin...         0.0      0.0  ...
# Zero to One: Notes on Startups, or How to Build...         0.0      0.0  ...
#
#                                                     ｆａｖｏｒｉｔｅｓ games  \
# title
# The Fellowship of the Ring (The Lord of the Rin...              0.0
# Zero to One: Notes on Startups, or How to Build...              0.0
#
#                                                     ｆａｖｏｒｉｔｅｓ george  \
# title
# The Fellowship of the Ring (The Lord of the Rin...               0.0
# Zero to One: Notes on Startups, or How to Build...               0.0
#
#                                                     ｆａｖｏｒｉｔｅｓ gothic  \
# title
# The Fellowship of the Ring (The Lord of the Rin...               0.0
# Zero to One: Notes on Startups, or How to Build...               0.0
#
#                                                     ｆａｖｏｒｉｔｅｓ neuroscience  \
# title
# The Fellowship of the Ring (The Lord of the Rin...                     0.0
# Zero to One: Notes on Startups, or How to Build...                     0.0
#
#                                                     ｆａｖｏｒｉｔｅｓ siege  \
# title
# The Fellowship of the Ring (The Lord of the Rin...              0.0
# Zero to One: Notes on Startups, or How to Build...              0.0
#
#                                                     ｆａｖｏｕｒｉｔｅｓ  ｍａｎｇａ  \
# title
# The Fellowship of the Ring (The Lord of the Rin...         0.0    0.0
# Zero to One: Notes on Startups, or How to Build...         0.0    0.0
#
#                                                     ｍａｎｇａ berserk  ｓｅｒｉｅｓ  \
# title
# The Fellowship of the Ring (The Lord of the Rin...            0.0     0.0
# Zero to One: Notes on Startups, or How to Build...            0.0     0.0
#
#                                                     ｓｅｒｉｅｓ carpathian
# title
# The Fellowship of the Ring (The Lord of the Rin...                0.0
# Zero to One: Notes on Startups, or How to Build...                0.0
#
# [2 rows x 144268 columns]

# %%
compare_df_filter = compare_df.loc[:, (compare_df != 0).any(axis=0)]

# %%
compare_df_filter
# Out:
#                                                         1001  1001 books  \
# title
# The Fellowship of the Ring (The Lord of the Rin...  0.104226    0.053119
# Zero to One: Notes on Startups, or How to Build...  0.000000    0.000000
#
#                                                     1001 literature      2014  \
# title
# The Fellowship of the Ring (The Lord of the Rin...         0.054469  0.021997
# Zero to One: Notes on Startups, or How to Build...         0.000000  0.000000
#
#                                                     2014 read      2015  \
# title
# The Fellowship of the Ring (The Lord of the Rin...   0.047961  0.021113
# Zero to One: Notes on Startups, or How to Build...   0.000000  0.030777
#
#                                                     2015 kindle  \
# title
# The Fellowship of the Ring (The Lord of the Rin...     0.000000
# Zero to One: Notes on Startups, or How to Build...     0.020869
#
#                                                     2015 shelfari  2015 wish  \
# title
# The Fellowship of the Ring (The Lord of the Rin...       0.042962   0.000000
# Zero to One: Notes on Startups, or How to Build...       0.000000   0.042812
#
#                                                         2016  ...       war  \
# title                                                         ...
# The Fellowship of the Ring (The Lord of the Rin...  0.021624  ...  0.043797
# Zero to One: Notes on Startups, or How to Build...  0.015760  ...  0.000000
#
#                                                     war lotr      wish  \
# title
# The Fellowship of the Ring (The Lord of the Rin...  0.115445  0.000000
# Zero to One: Notes on Startups, or How to Build...  0.000000  0.013279
#
#                                                     wish list      work  \
# title
# The Fellowship of the Ring (The Lord of the Rin...   0.000000  0.000000
# Zero to One: Notes on Startups, or How to Build...   0.013286  0.045804
#
#                                                     work product        ya  \
# title
# The Fellowship of the Ring (The Lord of the Rin...      0.000000  0.030334
# Zero to One: Notes on Startups, or How to Build...      0.077214  0.000000
#
#                                                     ya series    young  \
# title
# The Fellowship of the Ring (The Lord of the Rin...   0.035253  0.02703
# Zero to One: Notes on Startups, or How to Build...   0.000000  0.00000
#
#                                                     young adult
# title
# The Fellowship of the Ring (The Lord of the Rin...     0.027275
# Zero to One: Notes on Startups, or How to Build...     0.000000
#
# [2 rows x 373 columns]

# %%
compare_df[compare_df > 0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-92-f403704d0b6d> in <module>
# ----> 1 compare_df[compare_df > 0]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in f(self, other)
#    1577             # straight boolean comparisons we want to allow all columns
#    1578             # (regardless of dtype to pass thru) See #4537 for discussion.
# -> 1579             res = self._combine_const(other, func)
#    1580             return res.fillna(True).astype(bool)
#    1581
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _combine_const(self, other, func)
#    5401     def _combine_const(self, other, func):
#    5402         assert lib.is_scalar(other) or np.ndim(other) == 0
# -> 5403         return ops.dispatch_to_series(self, other, func)
#    5404
#    5405     def combine(self, other, func, fill_value=None, overwrite=True):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in dispatch_to_series(left, right, func, str_rep, axis)
#     594         raise NotImplementedError(right)
#     595
# --> 596     new_data = expressions.evaluate(column_op, str_rep, left, right)
#     597
#     598     result = left._constructor(new_data, index=left.index, copy=False)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     219     use_numexpr = use_numexpr and _bool_arith_check(op_str, a, b)
#     220     if use_numexpr:
# --> 221         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     222     return _evaluate_standard(op, op_str, a, b)
#     223
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     125
#     126     if result is None:
# --> 127         result = _evaluate_standard(op, op_str, a, b)
#     128
#     129     return result
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      68         _store_test_result(False)
#      69     with np.errstate(all="ignore"):
# ---> 70         return op(a, b)
#      71
#      72
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in column_op(a, b)
#     568
#     569         def column_op(a, b):
# --> 570             return {i: func(a.iloc[:, i], b) for i in range(len(a.columns))}
#     571
#     572     elif isinstance(right, ABCDataFrame):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in <dictcomp>(.0)
#     568
#     569         def column_op(a, b):
# --> 570             return {i: func(a.iloc[:, i], b) for i in range(len(a.columns))}
#     571
#     572     elif isinstance(right, ABCDataFrame):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in wrapper(self, other, axis)
#    1227
#    1228             with np.errstate(all="ignore"):
# -> 1229                 res = na_op(values, other)
#    1230             if is_scalar(res):
#    1231                 raise TypeError(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#    1089
#    1090         if is_object_dtype(x.dtype):
# -> 1091             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1092
#    1093         elif is_datetimelike_v_numeric(x, y):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in _comp_method_OBJECT_ARRAY(op, x, y)
#    1067         result = libops.vec_compare(x, y, op)
#    1068     else:
# -> 1069         result = libops.scalar_compare(x, y, op)
#    1070     return result
#    1071
#
# pandas/_libs/ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
matrix_df.iloc[18].isin(matrix_df.iloc[2165]).value_counts(normalize=True)
# Out:
# True     0.998572
# False    0.001428
# Name: The Fellowship of the Ring (The Lord of the Rings, #1), dtype: float64

# %%
# Book tags for Lord of the Rings
lord_of_the_rings_tags = pd.DataFrame(books_with_tags[books_with_tags['title']=='The Fellowship of the Ring (The Lord of the Rings, #1)']['tag_name'])
lord_of_the_rings_tags
# Out:
#                      tag_name
# 1800                  to-read
# 1801                  fantasy
# 1802                favorites
# 1803        currently-reading
# 1804              young-adult
# ...                       ...
# 1895  fantasy-science-fiction
# 1896                    elves
# 1897                  tolkien
# 1898                 fantasía
# 1899    the-lord-of-the-rings
#
# [100 rows x 1 columns]

# %%
# Find most frequent word used in tags
import nltk

top_N = 100
txt = lord_of_the_rings_tags.tag_name.str.lower().str.replace(r'-', ' ').str.cat(sep=' ') # Remove hyphens
words = nltk.tokenize.word_tokenize(txt)
word_dist = nltk.FreqDist(words)

stopwords = nltk.corpus.stopwords.words('english')
words_except_stop_dist = nltk.FreqDist(w for w in words if w not in stopwords) 
print('All frequencies, including STOPWORDS:')
print('=' * 60)
lor_rslt = pd.DataFrame(word_dist.most_common(top_N),
                    columns=['Word', 'Frequency'])
print(lor_rslt)
print('=' * 60)
lor_rslt = pd.DataFrame(words_except_stop_dist.most_common(top_N),
                    columns=['Word', 'Frequency']).set_index('Word')
matplotlib.style.use('ggplot')

lor_rslt.plot.bar(rot=0)
plt.show()

# %%
zero_rslt

# %%
top_N = 50

txt = lor_recs.tag_name.str.lower().str.replace(r'-', ' ').str.cat(sep=' ') # Remove hyphens
words = nltk.tokenize.word_tokenize(txt)
word_dist = nltk.FreqDist(words)

stopwords = nltk.corpus.stopwords.words('english')
words_except_stop_dist = nltk.FreqDist(w for w in words if w not in stopwords) 

print('All frequencies, including STOPWORDS:')
print('=' * 60)
rslt = pd.DataFrame(word_dist.most_common(top_N),
                    columns=['Word', 'Frequency'])
print(rslt)
print('=' * 60)

rslt = pd.DataFrame(words_except_stop_dist.most_common(top_N),
                    columns=['Word', 'Frequency']).set_index('Word')

matplotlib.style.use('ggplot')

rslt.plot.bar(rot=0)
plt.show()

# %%
lord_of_the_rings_tags.tag_name.mode()

# %%
# Book tags for Zero to One
zero_to_one_tags = pd.DataFrame(books_with_tags[books_with_tags['title']=='Zero to One: Notes on Startups, or How to Build the Future']['tag_name'])
zero_to_one_tags

# %%
# Find most frequent word used in tags
import nltk

top_N = 100
txt = zero_to_one_tags.tag_name.str.lower().str.replace(r'-', ' ').str.cat(sep=' ') # Remove hyphens
words = nltk.tokenize.word_tokenize(txt)
word_dist = nltk.FreqDist(words)

stopwords = nltk.corpus.stopwords.words('english')
words_except_stop_dist = nltk.FreqDist(w for w in words if w not in stopwords) 
print('All frequencies, including STOPWORDS:')
print('=' * 60)
zero_rslt = pd.DataFrame(word_dist.most_common(top_N),
                    columns=['Word', 'Frequency'])
print(zero_rslt)
print('=' * 60)
zero_rslt = pd.DataFrame(words_except_stop_dist.most_common(top_N),
                    columns=['Word', 'Frequency']).set_index('Word')
matplotlib.style.use('ggplot')

zero_rslt.plot.bar(rot=0)
plt.show()

# %%
# Concat 

df2_concat = pd.concat([lor_rslt,zero_rslt])
df2_concat

# %%
# Book tag for other  book
startup_tags = pd.DataFrame(books_with_tags[books_with_tags['title']=='Bossypants']['tag_name'])
startup_tags

# %%
# Check commonalities and differences within each
# False = different
# True = common
lord_of_the_rings_tags['tag_name'].isin(zero_to_one_tags['tag_name']).value_counts(normalize=True)

# %%
# Concat the two dataframes

df_concat = pd.concat([lord_of_the_rings_tags,zero_to_one_tags])
df_concat

# %%
df_concat[df_concat.duplicated(['tag_name'], keep=False)]

# %%
# Check commonalities and differences within each
# False = different
# True = common
lord_of_the_rings_tags['tag_name'].isin(startup_tags['tag_name']).value_counts(normalize=True)

# %%
# Concatenate the two dataframes
df_diff = pd.concat([lord_of_the_rings_tags,zero_to_one_tags]).drop_duplicates(keep=False)
pd.set_option('display.max_rows', 160)
df_diff

# %%
df_diff = pd.concat([lord_of_the_rings_tags, zero_to_one_tags]).loc[lord_of_the_rings_tags.index.symmetric_difference(zero_to_one_tags.index)]
df_diff.tail(60)

# %% [markdown]
# ### Find opposite of a word

# %%
import nltk 
from nltk.corpus import wordnet

# %%
synonyms = [] 
antonyms = [] 
  
for syn in wordnet.synsets('nice'): 
    for l in syn.lemmas(): 
        synonyms.append(l.name()) 
        if l.antonyms(): 
            antonyms.append(l.antonyms()[0].name()) 
  
print(set(antonyms))

# %%
#Checking antonym for the word "increase"
from nltk.corpus import wordnet
antonyms = []
for syn in wordnet.synsets("book"):
    for lm in syn.lemmas():
        if lm.antonyms():
            antonyms.append(lm.antonyms()[0].name()) #adding into antonyms
print(set(antonyms))

# %% [markdown]
# ### Filter for opposite of most frequent tag

# %%
# Displays all rows without truncating
pd.set_option('display.max_rows', None)
# pd.reset_option('display.max_rows', None)

pd.DataFrame(books_with_tags[books_with_tags['title']=='The Complete Guide to Middle-Earth']['tag_name'])

# %%
lor_recs_filter_business = lor_recs[lor_recs['tag_name'].str.contains("nonfiction")]
lor_recs_filter_business

# %%
newdf = lor_recs[lor_recs['tag_name'] != 'fantasy'
